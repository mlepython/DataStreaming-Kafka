# %%
import os
from dotenv import load_dotenv
from pathlib import Path
from sqlalchemy import create_engine
import psycopg2

# %%
load_dotenv(dotenv_path=Path(os.getcwd()).parent/".env")
username = os.getenv('PG_USERNAME')
password = os.getenv('PG_PASSWORD')
database_name = 'salesdata'

# %%
connection = psycopg2.connect(
    user=username,
    password=password,
    host='localhost',
    port='5432',
    database=database_name
)
cursor = connection.cursor()

# %%
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/{database_name}')

# %%
# Print PostgreSQL details
print("PostgreSQL server information")
print(connection.get_dsn_parameters(), "\n")
# Executing a SQL query
cursor.execute("SELECT version();")
# Fetch result
record = cursor.fetchone()
print("You are connected to - ", record, "\n")
# Out:
# PostgreSQL server information
# {'user': 'postgres', 'channel_binding': 'prefer', 'dbname': 'salesdata', 'host': 'localhost', 'port': '5432', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'sslcertmode': 'allow', 'sslsni': '1', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'gssdelegation': '0', 'target_session_attrs': 'any', 'load_balance_hosts': 'disable'}
#
# You are connected to -  ('PostgreSQL 16.1, compiled by Visual C++ build 1937, 64-bit',)

# %%
# Execute a query
cursor.execute('SELECT * FROM "transactions_FACT"')

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'dff420ec-248a-4659-aaf2-ba6a4229bb73', datetime.datetime(2024, 2, 3, 17, 24, 13), 105.35, 12.64, 117.99, 'CUST001', 'STORE002', 3, 1)
# (4, '4adf49f0-2e2d-4625-88b4-3b4097c09a35', datetime.datetime(2023, 5, 21, 17, 5, 17), 33.8, 1.69, 35.49, 'CUST008', 'STORE004', 1, 2)
# (9, 'e388a080-e2a3-429a-93b9-e2cd1f975218', datetime.datetime(2023, 3, 21, 22, 55, 31), 49.1, 7.37, 56.47, 'CUST003', 'STORE005', 1, 5)
# (10, '46a9368f-673f-47d3-8415-306158389ec9', datetime.datetime(2023, 3, 25, 20, 38, 43), 95.75, 14.36, 110.11, 'CUST008', 'STORE005', 2, 6)
# (11, 'eafaf2c6-57e4-4691-aa9d-6c598d2cc563', datetime.datetime(2023, 3, 6, 23, 49, 27), 56.6, 8.49, 65.09, 'CUST002', 'STORE005', 1, 7)
# (12, 'd2091426-1d44-4ac0-98ea-a45e180bad01', datetime.datetime(2023, 8, 14, 2, 10, 36), 70.95, 8.51, 79.46, 'CUST008', 'STORE002', 1, 8)
# (13, '98ad003a-b989-4529-bdcb-3c8214fe3bb3', datetime.datetime(2023, 4, 3, 6, 5, 55), 82.15, 4.11, 86.26, 'CUST007', 'STORE004', 5, 9)
# (14, '1b3f58a6-1a46-4458-8571-921ba816ede2', datetime.datetime(2023, 8, 8, 12, 5, 18), 71.7, 9.32, 81.02, 'CUST009', 'STORE001', 4, 10)
# (15, '3ce9b660-e490-452c-8397-b7e76729acf0', datetime.datetime(2023, 5, 18, 15, 50, 35), 65.85, 9.88, 75.73, 'CUST001', 'STORE005', 2, 11)
# (16, '6870ccad-4f81-464e-81b8-bdb7b305d2c5', datetime.datetime(2023, 8, 1, 20, 53, 31), 31.0, 4.64, 35.64, 'CUST004', 'STORE003', 4, 12)
# (17, '78e03648-f372-4a10-b767-f1dd6bf66af8', datetime.datetime(2023, 2, 23, 8, 59, 11), 111.1, 16.64, 127.74, 'CUST009', 'STORE003', 3, 13)
# (18, '02f4b55f-035e-4088-87a8-e34900958089', datetime.datetime(2023, 8, 5, 22, 9, 12), 90.45, 13.57, 104.02, 'CUST006', 'STORE005', 4, 14)
# (19, '424652e4-3ada-469d-8303-e3be6ebb97fa', datetime.datetime(2023, 12, 16, 22, 15, 19), 21.25, 2.55, 23.8, 'CUST005', 'STORE002', 2, 15)
# (20, '947b0666-907f-402c-93e1-f4270e55d89f', datetime.datetime(2023, 7, 24, 9, 42, 49), 129.65, 15.56, 145.21, 'CUST005', 'STORE002', 3, 16)
# (21, '46b48e6a-abc0-4f97-9d03-7026d5faf8b9', datetime.datetime(2023, 6, 6, 9, 55, 40), 23.6, 1.18, 24.78, 'CUST006', 'STORE004', 1, 17)
# (22, '30dd8960-9268-4b46-b377-5436d01d0b9e', datetime.datetime(2023, 2, 28, 16, 41, 6), 52.55, 2.63, 55.18, 'CUST005', 'STORE004', 5, 18)
# (23, '4659a20e-cd54-4cd8-b6a9-56e7a64fc213', datetime.datetime(2023, 4, 27, 9, 52, 49), 109.2, 16.38, 125.58, 'CUST008', 'STORE005', 1, 19)
# (24, '8fcc95aa-9dc0-4db2-b8c2-d7825f3abe1f', datetime.datetime(2023, 8, 23, 19, 12, 57), 42.0, 5.04, 47.04, 'CUST008', 'STORE002', 1, 20)
# (25, 'e59d0fd7-28dc-487b-a3d6-c7a21ef77c7e', datetime.datetime(2023, 7, 12, 6, 54, 45), 25.8, 3.87, 29.67, 'CUST005', 'STORE005', 1, 21)
# (26, 'a584ad4d-a19a-476f-b9fc-1a3d1cddfc8f', datetime.datetime(2023, 9, 12, 11, 16, 43), 67.35, 10.09, 77.44, 'CUST003', 'STORE003', 2, 22)
# (27, '85b4f973-ae13-46bd-8ea9-4172a47bbb36', datetime.datetime(2023, 9, 3, 15, 10, 14), 14.2, 1.7, 15.9, 'CUST001', 'STORE002', 2, 23)
# (28, 'e1fb09f9-1967-4435-86a5-4552c25f7bf4', datetime.datetime(2023, 6, 21, 6, 30, 1), 88.45, 13.27, 101.72, 'CUST003', 'STORE005', 5, 24)
# (29, 'd17ebc97-b914-457b-9da8-a2c47bb8b93a', datetime.datetime(2023, 9, 15, 14, 12, 22), 93.05, 12.1, 105.15, 'CUST005', 'STORE001', 3, 25)
# (30, 'e572d40f-3b98-4750-8abd-4eab3de30de8', datetime.datetime(2023, 11, 29, 15, 1, 54), 79.6, 3.98, 83.58, 'CUST004', 'STORE004', 1, 26)
# (31, 'b3332121-e831-4294-ad17-925176efa897', datetime.datetime(2023, 8, 18, 6, 47, 50), 88.15, 13.2, 101.35, 'CUST009', 'STORE003', 2, 27)
# (32, '3137d91c-04bf-432f-95ef-2c9917c25bc7', datetime.datetime(2023, 10, 20, 4, 33, 45), 129.35, 19.4, 148.75, 'CUST005', 'STORE005', 1, 28)
# (33, '617897ca-358e-4174-94b8-58ace701a1c0', datetime.datetime(2023, 10, 25, 7, 53, 7), 14.15, 2.12, 16.27, 'CUST003', 'STORE003', 5, 29)
# (34, 'c6a61e83-683f-4540-918e-22f79b8ff757', datetime.datetime(2023, 9, 9, 1, 29, 47), 47.3, 2.36, 49.66, 'CUST004', 'STORE004', 5, 30)
# (35, 'b90e915b-8779-49e4-b722-494071a164c8', datetime.datetime(2023, 10, 9, 1, 16, 10), 53.9, 2.7, 56.59, 'CUST003', 'STORE004', 1, 31)
# (36, '7ce26789-2e59-45ee-8eaf-8e0c037dd6eb', datetime.datetime(2023, 12, 21, 20, 5, 50), 43.5, 2.18, 45.67, 'CUST006', 'STORE004', 3, 32)
# (37, 'b1b1772b-2be1-495d-82cc-63411b4174a2', datetime.datetime(2023, 1, 8, 14, 21, 3), 67.95, 8.15, 76.1, 'CUST009', 'STORE002', 3, 33)
# (38, 'd7d80b63-895f-4208-88c1-010fe28f11e3', datetime.datetime(2023, 10, 16, 4, 18, 59), 100.2, 15.0, 115.2, 'CUST004', 'STORE003', 5, 34)
# (39, 'ff3da1a0-fa3c-4713-af91-fb7147539a58', datetime.datetime(2023, 5, 15, 15, 39, 59), 87.25, 10.47, 97.72, 'CUST009', 'STORE002', 3, 35)
# (40, '2a5d93a1-3e52-4336-82b7-1b6f842a1bae', datetime.datetime(2023, 11, 14, 7, 36, 5), 43.85, 6.58, 50.43, 'CUST005', 'STORE005', 4, 36)
# (41, 'a0aedb31-adbb-4229-85fe-ab3b4291bafb', datetime.datetime(2023, 10, 1, 0, 42, 44), 58.7, 2.94, 61.64, 'CUST007', 'STORE004', 5, 37)
# (42, '2038e269-06bc-4e3a-aa08-606086e5c842', datetime.datetime(2023, 7, 18, 10, 50, 43), 57.0, 8.54, 65.54, 'CUST007', 'STORE003', 1, 38)
# (43, 'adb5405e-f1c4-4c04-9e16-52bcf53f5daa', datetime.datetime(2023, 2, 4, 2, 16, 28), 31.9, 3.83, 35.73, 'CUST006', 'STORE002', 3, 39)
# (44, '3051bc61-4719-4f05-a9fe-8fac742727c0', datetime.datetime(2023, 10, 26, 13, 0, 42), 100.3, 5.02, 105.32, 'CUST007', 'STORE004', 1, 40)
# (45, '7ae9f978-fa5c-45f4-bbaf-e96da7fe191a', datetime.datetime(2023, 9, 3, 23, 20, 4), 119.5, 15.54, 135.03, 'CUST006', 'STORE001', 5, 23)
# (46, 'd2a94429-b514-4520-8757-9d4c835ba6b1', datetime.datetime(2023, 9, 26, 2, 53, 24), 67.75, 8.81, 76.56, 'CUST001', 'STORE001', 4, 42)
# (47, 'e2766eca-db1d-4810-b089-293dda1cb92a', datetime.datetime(2023, 12, 12, 3, 59, 28), 21.2, 2.54, 23.74, 'CUST008', 'STORE002', 5, 43)
# (48, '68b691a2-6e42-4c5a-92e9-0aada8518ea3', datetime.datetime(2023, 6, 23, 11, 2, 19), 16.4, 2.46, 18.86, 'CUST002', 'STORE003', 3, 44)
# (49, '22ac79f5-9b8c-4f51-bf78-2401f2fa25b5', datetime.datetime(2023, 3, 29, 8, 49, 8), 29.75, 3.57, 33.32, 'CUST004', 'STORE002', 2, 45)
# (50, '30408c4d-9ceb-446a-9dce-f86c0884ba6b', datetime.datetime(2023, 3, 3, 14, 28, 5), 86.25, 12.94, 99.19, 'CUST006', 'STORE005', 2, 46)
# (51, '33e1971f-4a74-4f46-a20c-5b6035e365e1', datetime.datetime(2023, 11, 19, 22, 13, 43), 36.0, 5.4, 41.4, 'CUST010', 'STORE005', 4, 47)
# (52, '44292e82-b42d-47c8-af12-77703cb96dcf', datetime.datetime(2023, 4, 22, 10, 8, 3), 72.3, 10.83, 83.13, 'CUST009', 'STORE003', 4, 48)
# (53, '4a215c68-5444-4afc-a901-fd38c47e55f9', datetime.datetime(2023, 11, 30, 9, 42, 58), 122.15, 14.66, 136.81, 'CUST010', 'STORE002', 3, 49)
# (54, 'e95b75d6-200f-423f-a31f-9d0c1aa7d9aa', datetime.datetime(2023, 6, 29, 1, 6, 41), 68.05, 10.19, 78.24, 'CUST009', 'STORE003', 5, 50)
# (55, '51411cdb-e17e-42e0-8ac4-839687aa1b6c', datetime.datetime(2023, 11, 15, 1, 29, 14), 88.05, 13.21, 101.26, 'CUST003', 'STORE005', 3, 51)
# (56, '1f8852d4-497a-45e1-a652-14d0ef0b5387', datetime.datetime(2023, 9, 6, 14, 35, 14), 100.5, 15.05, 115.55, 'CUST005', 'STORE003', 2, 52)
# (57, '3640bebf-85bc-43c9-b41f-fddc38cda4ad', datetime.datetime(2023, 6, 17, 10, 58, 55), 77.7, 10.1, 87.8, 'CUST009', 'STORE001', 1, 53)
# (58, '5b5252f5-dc90-4520-9fb1-a0529b2fd99e', datetime.datetime(2023, 4, 17, 0, 20, 9), 15.6, 1.87, 17.47, 'CUST009', 'STORE002', 2, 54)
# (59, '5e109e47-bbe4-4c64-8187-173d4c254b03', datetime.datetime(2023, 7, 6, 8, 20, 39), 31.4, 4.71, 36.11, 'CUST003', 'STORE005', 3, 55)
# (60, 'c31aa13a-40fb-4e53-89ff-0c3feefc0a4f', datetime.datetime(2023, 2, 14, 9, 11, 26), 44.4, 5.33, 49.73, 'CUST001', 'STORE002', 3, 56)
# (61, 'f776030e-c167-4817-98a7-ca75eafceab6', datetime.datetime(2023, 2, 26, 3, 35, 42), 95.65, 4.78, 100.43, 'CUST009', 'STORE004', 4, 57)
# (62, '8d2252dd-ac3f-4972-b0e7-5d9bacaf94ca', datetime.datetime(2023, 9, 14, 1, 23, 19), 8.6, 1.03, 9.63, 'CUST001', 'STORE002', 2, 58)
# (63, 'f603e90b-08d5-4473-b100-3a31ca2fd8d3', datetime.datetime(2023, 9, 13, 2, 49, 50), 124.8, 18.72, 143.52, 'CUST001', 'STORE005', 2, 59)
# (64, 'd68a9e50-8c3f-4420-ab11-56dd4f2edc4b', datetime.datetime(2023, 12, 26, 21, 19, 41), 32.05, 3.85, 35.9, 'CUST007', 'STORE002', 4, 60)
# (65, 'd5a77f0f-6960-45c8-af99-0af3f6d0b463', datetime.datetime(2023, 6, 21, 10, 56, 27), 33.2, 4.97, 38.17, 'CUST006', 'STORE003', 3, 24)
# (66, '443a3ce5-1127-47e2-8017-6b1b06014736', datetime.datetime(2023, 10, 5, 0, 45, 16), 86.7, 10.4, 97.1, 'CUST004', 'STORE002', 4, 62)
# (67, '5704638d-7433-4e3c-af74-b132600deee9', datetime.datetime(2023, 5, 30, 17, 30, 15), 113.4, 5.67, 119.07, 'CUST007', 'STORE004', 3, 63)
# (68, '1e113f70-9d88-48da-93e4-f86fdcf0007b', datetime.datetime(2023, 12, 28, 9, 49, 3), 102.75, 12.33, 115.08, 'CUST010', 'STORE002', 3, 64)
# (69, '57ecb695-f8ac-4194-8bfd-7d4480dd84d0', datetime.datetime(2023, 9, 20, 5, 11, 10), 65.7, 3.28, 68.98, 'CUST005', 'STORE004', 3, 65)
# (70, 'd8c3101b-e242-4fd3-a43c-84f93255dc31', datetime.datetime(2023, 12, 19, 9, 16, 18), 104.5, 12.54, 117.04, 'CUST003', 'STORE002', 5, 66)
# (71, '2b5673f4-5ca0-44e3-a67b-eeffbd8f570b', datetime.datetime(2023, 12, 21, 9, 39, 1), 86.85, 13.01, 99.86, 'CUST002', 'STORE003', 3, 32)
# (72, '53733a60-6b97-4650-a274-db04d91f73a6', datetime.datetime(2023, 8, 23, 10, 4, 1), 69.8, 9.07, 78.87, 'CUST004', 'STORE001', 2, 20)
# (73, '1e5b8843-6b54-46e4-8cb3-286ca1ca79c3', datetime.datetime(2023, 11, 25, 6, 42, 29), 43.95, 5.71, 49.66, 'CUST004', 'STORE001', 4, 69)
# (74, 'c85b097e-91b4-4283-987c-960908583b19', datetime.datetime(2023, 8, 21, 9, 32, 8), 59.5, 8.91, 68.41, 'CUST002', 'STORE003', 3, 70)
# (75, '64062cb5-a110-4ae7-82fb-ec9d1ee69b2f', datetime.datetime(2023, 4, 27, 10, 32, 53), 57.45, 7.47, 64.92, 'CUST010', 'STORE001', 1, 19)
# (76, 'e01d7e11-0386-470a-af6a-b47c9113c0d7', datetime.datetime(2023, 4, 9, 19, 19, 37), 67.6, 8.11, 75.71, 'CUST004', 'STORE002', 3, 72)
# (77, 'd17bf7aa-5f1c-4e8a-a445-e92c27fcefd6', datetime.datetime(2023, 5, 17, 9, 0, 30), 23.6, 3.53, 27.13, 'CUST006', 'STORE003', 4, 73)
# (78, '62c72d27-6315-4bbc-ad16-367b6d7f6a0a', datetime.datetime(2023, 7, 11, 11, 3, 25), 89.5, 13.42, 102.92, 'CUST004', 'STORE005', 4, 74)
# (79, 'd9f65f04-60fe-4d9d-9603-48030eb60512', datetime.datetime(2023, 10, 12, 23, 28, 55), 144.5, 18.79, 163.28, 'CUST003', 'STORE001', 2, 75)
# (80, '43108f34-874c-40b2-85ba-6866cee9a5e9', datetime.datetime(2023, 2, 15, 7, 5), 88.9, 13.31, 102.21, 'CUST002', 'STORE003', 2, 76)
# (81, '1ca3a18f-17bc-4a20-9d1d-c14c1c5c4486', datetime.datetime(2023, 7, 14, 18, 16, 56), 130.15, 19.52, 149.67, 'CUST005', 'STORE005', 2, 77)
# (82, '777c1565-e97f-493c-befe-e6d36d90a44a', datetime.datetime(2023, 6, 12, 22, 14, 10), 64.25, 3.21, 67.46, 'CUST001', 'STORE004', 5, 78)
# (83, '9f69ba1e-c38c-419b-ac91-4b79956739fd', datetime.datetime(2023, 11, 29, 18, 11, 23), 61.7, 9.24, 70.94, 'CUST010', 'STORE003', 1, 26)
# (84, '97ffb1eb-0a3f-45e0-86b2-51d9755d4f39', datetime.datetime(2023, 1, 22, 5, 53, 50), 86.05, 12.89, 98.94, 'CUST009', 'STORE003', 1, 80)
# (85, '33735fed-fdc4-47c4-876d-2c2ef6c48bb8', datetime.datetime(2023, 1, 5, 2, 34, 2), 101.35, 5.07, 106.42, 'CUST010', 'STORE004', 3, 81)
# (86, '70277b60-ce48-4dca-b2fc-6e583c20309f', datetime.datetime(2023, 8, 26, 7, 10, 46), 23.0, 2.99, 25.99, 'CUST009', 'STORE001', 4, 82)
# (87, '7f01bbe0-649b-4a9f-99e4-ee8ef94ce7dc', datetime.datetime(2023, 3, 6, 7, 58, 40), 117.0, 17.55, 134.55, 'CUST008', 'STORE005', 4, 7)
# (88, 'af6178c3-a180-43e2-847d-28c8c1d1f2e8', datetime.datetime(2023, 1, 16, 2, 44, 16), 23.6, 1.18, 24.78, 'CUST007', 'STORE004', 4, 84)
# (89, 'd6a5f55f-0a49-4f36-9848-c254a7fee4e5', datetime.datetime(2023, 12, 5, 18, 26, 55), 33.9, 5.08, 38.98, 'CUST007', 'STORE005', 5, 85)
# (90, '1046a822-a149-4669-8066-38bcbc7e6184', datetime.datetime(2023, 7, 3, 14, 31, 40), 29.35, 3.52, 32.87, 'CUST008', 'STORE002', 2, 86)
# (91, '94fcab7b-7ece-4a57-9193-3b929567f3f8', datetime.datetime(2023, 11, 21, 19, 56, 7), 103.2, 15.45, 118.65, 'CUST010', 'STORE003', 3, 87)
# (92, '263f3093-9ced-4170-93c1-3d9f08c7a8b8', datetime.datetime(2023, 1, 24, 20, 20, 29), 86.15, 11.2, 97.35, 'CUST006', 'STORE001', 1, 88)
# (93, 'f92ed887-2cbc-406e-be3f-7aa70e1b8ba9', datetime.datetime(2023, 2, 8, 6, 34, 49), 124.45, 16.18, 140.63, 'CUST007', 'STORE001', 1, 89)
# (94, '9ba1b2b8-701e-4c77-93d9-45d98292159e', datetime.datetime(2023, 1, 31, 11, 54, 41), 44.3, 5.76, 50.06, 'CUST005', 'STORE001', 3, 90)
# (95, 'ece2e65c-ae9d-45af-bd48-3c889793d868', datetime.datetime(2023, 2, 3, 6, 14, 6), 21.25, 1.06, 22.31, 'CUST010', 'STORE004', 2, 91)
# (96, '66827898-7533-4e74-8959-57dc81706309', datetime.datetime(2023, 1, 20, 14, 39, 44), 18.4, 0.92, 19.32, 'CUST004', 'STORE004', 5, 92)
# (97, '70bda658-a9fe-4eff-8e29-ebd952b62e1a', datetime.datetime(2023, 6, 27, 13, 57, 23), 95.95, 14.37, 110.32, 'CUST007', 'STORE003', 1, 93)
# (98, '26264e53-f121-4ad4-94a3-39a98a186df1', datetime.datetime(2023, 8, 13, 21, 36, 30), 123.2, 6.16, 129.36, 'CUST001', 'STORE004', 3, 94)
# (99, '55e847b9-8388-4e55-8413-17ac432317d8', datetime.datetime(2023, 11, 3, 9, 24, 54), 90.95, 4.55, 95.5, 'CUST006', 'STORE004', 1, 95)
# (100, '49db4a35-6b4d-4aeb-9213-cc3cbd68f9dc', datetime.datetime(2023, 10, 4, 11, 22, 14), 25.9, 3.37, 29.27, 'CUST005', 'STORE001', 5, 96)
# (101, 'ff925de6-8196-489e-aeac-e51e0b31991a', datetime.datetime(2023, 9, 28, 19, 21, 23), 21.5, 3.22, 24.72, 'CUST007', 'STORE003', 4, 97)
# (102, '60cee813-fd30-4d7d-b580-5a2a476fa82d', datetime.datetime(2023, 12, 22, 12, 5, 53), 90.75, 13.61, 104.36, 'CUST002', 'STORE005', 1, 98)
# (103, 'bf387864-69ea-4d21-a571-74232ad9af62', datetime.datetime(2023, 2, 25, 20, 17, 19), 86.9, 11.3, 98.2, 'CUST007', 'STORE001', 1, 99)
# (104, '2a8686b4-a2df-4342-b388-b933a10aa0b9', datetime.datetime(2023, 3, 1, 18, 38, 56), 52.25, 6.27, 58.52, 'CUST001', 'STORE002', 3, 100)
# (105, '1d80be90-fc62-43d7-8571-f05f38cc92a5', datetime.datetime(2023, 3, 4, 9, 39, 16), 98.75, 4.94, 103.69, 'CUST006', 'STORE004', 1, 101)
# (106, 'b87360f1-f519-46ab-b8e3-7e62f6b46af2', datetime.datetime(2023, 1, 31, 16, 10, 53), 109.45, 13.13, 122.58, 'CUST002', 'STORE002', 3, 90)
# (107, 'eeb2a6ff-8110-4d97-b9e2-a07105cb6e64', datetime.datetime(2023, 2, 27, 17, 36, 44), 95.1, 4.76, 99.86, 'CUST006', 'STORE004', 1, 103)
# (108, '2a6f067a-29c9-426c-bf6d-c92d923c6af4', datetime.datetime(2023, 1, 1, 12, 31, 3), 107.75, 16.14, 123.89, 'CUST008', 'STORE003', 5, 304)
# (109, '08ab3bf2-cbbd-45b7-93d1-0fc6bcd3f7cd', datetime.datetime(2023, 12, 25, 7, 1, 48), 61.4, 7.98, 69.38, 'CUST008', 'STORE001', 2, 305)
# (110, 'e06e3a28-f7f8-4abb-9521-e23485fe18a9', datetime.datetime(2023, 8, 25, 19, 35, 33), 69.75, 9.07, 78.82, 'CUST006', 'STORE001', 3, 306)
# (111, '56c0c05c-d407-4ee9-85a3-189f8b1e6b2a', datetime.datetime(2023, 9, 12, 23, 35, 45), 38.9, 5.83, 44.73, 'CUST003', 'STORE003', 2, 22)
# (112, 'a4ea1eec-d7b0-408f-8272-7ae1d0a5534a', datetime.datetime(2023, 8, 18, 1, 15, 27), 108.2, 16.2, 124.4, 'CUST008', 'STORE003', 1, 27)
# (113, '24c03d19-709e-4104-9f01-0d0f051b642a', datetime.datetime(2023, 2, 6, 23, 5, 10), 85.05, 4.25, 89.3, 'CUST010', 'STORE004', 2, 309)
# (114, '2ef68c66-68af-4315-8e0c-e146e5094124', datetime.datetime(2023, 6, 27, 14, 55, 43), 39.4, 5.12, 44.52, 'CUST007', 'STORE001', 3, 93)
# (115, 'ed0fcef3-0b3e-4fbe-b75a-d4ba4eb5b6a7', datetime.datetime(2023, 7, 28, 9, 33, 41), 43.3, 5.2, 48.5, 'CUST010', 'STORE002', 5, 311)
# (116, '87323cfb-2757-4b53-a76d-b7592208eeb5', datetime.datetime(2023, 3, 5, 2, 28, 43), 25.35, 3.04, 28.39, 'CUST006', 'STORE002', 1, 312)
# (1223, '1f642a3f-6873-4b92-85e4-52e2c9912dd0', datetime.datetime(2023, 7, 15, 7, 23, 29), 38.1, 5.71, 43.81, 'CUST008', 'STORE003', 3, 457)
# (117, '9a8b91b2-f7c3-4040-9342-869651bf3295', datetime.datetime(2023, 6, 10, 18, 54, 25), 46.7, 7.0, 53.71, 'CUST010', 'STORE005', 3, 313)
# (118, 'a74876a1-6eb1-49d6-9b39-58dc0c7886fc', datetime.datetime(2023, 6, 25, 1, 23, 42), 36.5, 5.47, 41.97, 'CUST004', 'STORE003', 3, 314)
# (119, 'c7708a73-223d-41f3-8510-05c2275cc36b', datetime.datetime(2023, 7, 1, 20, 38, 30), 54.35, 8.14, 62.49, 'CUST001', 'STORE003', 3, 315)
# (120, '5293cfcd-0f52-41f3-830b-ee374dd70146', datetime.datetime(2023, 9, 15, 7, 16, 54), 115.85, 15.06, 130.91, 'CUST007', 'STORE001', 2, 25)
# (121, '829138dd-1bf2-4572-8d64-9fba2deb5800', datetime.datetime(2023, 5, 26, 10, 2, 48), 73.8, 11.07, 84.87, 'CUST008', 'STORE005', 1, 317)
# (122, '0c9a5f56-605f-42ce-9b86-e245e1ab7ff4', datetime.datetime(2023, 7, 13, 7, 56, 38), 56.15, 7.3, 63.45, 'CUST005', 'STORE001', 4, 318)
# (123, '181c965d-48a6-474e-ac5c-f440c461a145', datetime.datetime(2023, 10, 4, 12, 31, 47), 100.8, 15.12, 115.92, 'CUST009', 'STORE005', 1, 96)
# (124, '834f9b38-b0c0-4a49-95e7-b324b31b41ef', datetime.datetime(2023, 1, 10, 21, 57, 41), 74.3, 3.72, 78.02, 'CUST005', 'STORE004', 4, 320)
# (125, '737551b1-ef7a-4027-bd49-e3af53120f33', datetime.datetime(2023, 9, 4, 4, 40, 2), 128.55, 19.25, 147.8, 'CUST005', 'STORE003', 1, 321)
# (126, '864a5c06-3916-4c88-b249-027a34332755', datetime.datetime(2023, 3, 18, 20, 9, 24), 16.1, 2.42, 18.52, 'CUST004', 'STORE005', 3, 322)
# (127, '946c2aa1-3e03-4620-9857-b7219219e36e', datetime.datetime(2023, 5, 16, 22, 2, 11), 33.25, 4.99, 38.24, 'CUST007', 'STORE005', 4, 323)
# (128, 'dba0b4eb-f5a9-4d99-becf-482bf2ac57ae', datetime.datetime(2023, 10, 22, 12, 53, 49), 70.4, 8.45, 78.85, 'CUST002', 'STORE002', 1, 324)
# (129, 'ab4b05c9-3305-42af-b0f0-af503663f1a9', datetime.datetime(2023, 8, 18, 21, 20, 2), 79.1, 10.28, 89.38, 'CUST005', 'STORE001', 4, 27)
# (130, '39e840b9-15c9-4879-afff-c85d96515d56', datetime.datetime(2023, 8, 17, 9, 0, 14), 65.95, 9.88, 75.83, 'CUST003', 'STORE003', 1, 326)
# (131, '298682ea-056d-467f-8404-86a90d8fc35b', datetime.datetime(2023, 12, 20, 23, 18, 5), 107.25, 16.09, 123.34, 'CUST009', 'STORE005', 2, 327)
# (132, '0337284e-4d4f-4f86-a005-06e327e7f5e8', datetime.datetime(2023, 4, 25, 19, 33, 30), 65.75, 3.29, 69.04, 'CUST006', 'STORE004', 4, 328)
# (133, 'ea45acc5-0943-4398-933c-c3aa14d9bc13', datetime.datetime(2023, 3, 13, 11, 51, 24), 59.05, 2.95, 62.0, 'CUST002', 'STORE004', 5, 329)
# (134, 'ea07e883-3f76-4a67-809a-0f142299ba36', datetime.datetime(2023, 5, 1, 1, 23, 59), 77.85, 10.12, 87.97, 'CUST002', 'STORE001', 4, 330)
# (135, 'ce94b12b-b261-4e21-85d5-38f08251add0', datetime.datetime(2023, 9, 12, 20, 48, 10), 58.7, 7.63, 66.33, 'CUST004', 'STORE001', 1, 22)
# (136, 'b2d7069d-b75b-4f9d-806b-8ba4c380d0a4', datetime.datetime(2023, 3, 25, 3, 51, 10), 110.85, 14.41, 125.26, 'CUST006', 'STORE001', 3, 6)
# (137, '4c5ad0bc-d4ef-4397-8265-bc70e225eff8', datetime.datetime(2023, 8, 3, 7, 26, 37), 20.85, 3.12, 23.97, 'CUST001', 'STORE003', 5, 333)
# (138, 'bb00cb77-0cd9-48b0-92f0-72a5216e0a89', datetime.datetime(2023, 5, 6, 18, 10, 1), 44.7, 6.69, 51.39, 'CUST003', 'STORE003', 4, 334)
# (139, '17fcb395-728c-4e9f-99fc-9da0b4db6e7a', datetime.datetime(2023, 12, 11, 22, 36, 25), 56.05, 8.39, 64.44, 'CUST001', 'STORE003', 3, 335)
# (140, '3aea39c3-7ac9-42bf-8a4c-4ff4c1ad507e', datetime.datetime(2023, 2, 25, 5, 25, 51), 29.45, 3.53, 32.98, 'CUST008', 'STORE002', 2, 99)
# (141, '9dca7f3a-3893-4558-b5c0-223348a9aaac', datetime.datetime(2023, 12, 4, 9, 43, 1), 13.2, 1.58, 14.78, 'CUST007', 'STORE002', 4, 337)
# (142, 'b7ac403f-ef87-4ac5-ac79-ebd6db21a83e', datetime.datetime(2023, 3, 22, 4, 29, 14), 104.9, 5.25, 110.14, 'CUST009', 'STORE004', 2, 338)
# (143, '6029f8bc-eb74-4b3b-aacb-b3a1ecb407a8', datetime.datetime(2023, 9, 11, 9, 30, 56), 95.9, 11.51, 107.41, 'CUST001', 'STORE002', 5, 339)
# (144, '0c9518ce-5388-4d77-a03a-b98e2a8436d4', datetime.datetime(2023, 2, 23, 0, 28, 36), 12.9, 0.65, 13.54, 'CUST003', 'STORE004', 3, 13)
# (145, '3ffffd9e-85f1-481a-8daa-9ac9627c16d3', datetime.datetime(2023, 9, 9, 2, 32, 40), 28.5, 4.27, 32.77, 'CUST002', 'STORE003', 1, 30)
# (146, '6b662a6d-365a-4bce-8a12-6839b260bd22', datetime.datetime(2023, 4, 24, 10, 38), 99.1, 11.89, 110.99, 'CUST001', 'STORE002', 3, 342)
# (147, '70626e6f-6190-43a3-81ee-2799b1effd7f', datetime.datetime(2023, 11, 23, 1, 6, 13), 98.55, 12.81, 111.36, 'CUST002', 'STORE001', 5, 343)
# (148, '902fbdaa-b426-4e6f-b896-e1d673e098d8', datetime.datetime(2023, 12, 2, 18, 49, 41), 99.5, 11.94, 111.44, 'CUST005', 'STORE002', 3, 344)
# (149, '2fff47f6-8a24-494a-b6d3-ba024d460e5d', datetime.datetime(2023, 4, 19, 22, 20, 41), 77.45, 9.29, 86.74, 'CUST010', 'STORE002', 2, 345)
# (150, '442ea136-aaca-4dd6-8c3b-e93a153b2add', datetime.datetime(2023, 6, 3, 16, 27, 10), 36.0, 4.68, 40.68, 'CUST009', 'STORE001', 1, 346)
# (151, '69069238-be54-4132-96e4-a5824f7a0138', datetime.datetime(2023, 10, 13, 7, 55, 52), 100.75, 13.1, 113.85, 'CUST003', 'STORE001', 1, 347)
# (152, '2cc018f7-dcae-42ca-b743-5fb5ccbf012b', datetime.datetime(2023, 11, 21, 9, 45, 28), 47.5, 7.12, 54.62, 'CUST001', 'STORE005', 4, 87)
# (153, '5c5b45da-b298-4dc4-a131-d5b421534a80', datetime.datetime(2023, 10, 15, 11, 43, 7), 118.85, 17.8, 136.65, 'CUST003', 'STORE003', 1, 349)
# (154, '561bd5a4-fe97-4058-a2b1-34bda40d35ae', datetime.datetime(2023, 11, 6, 19, 40, 24), 73.7, 11.04, 84.74, 'CUST005', 'STORE003', 1, 350)
# (155, 'f9777db4-9659-4eb0-9877-5666221c0cc9', datetime.datetime(2023, 9, 4, 3, 17, 33), 114.9, 13.79, 128.69, 'CUST009', 'STORE002', 5, 321)
# (156, '4d744b2e-1ae8-4cec-a88a-28cc8e30fb93', datetime.datetime(2023, 4, 14, 4, 2, 59), 115.75, 5.79, 121.54, 'CUST001', 'STORE004', 5, 352)
# (157, '8aae4986-fc11-4433-acf6-40ae077ea64b', datetime.datetime(2023, 7, 17, 2, 39, 59), 80.7, 10.49, 91.19, 'CUST006', 'STORE001', 4, 353)
# (158, '636aa19c-2687-4efa-87af-dd886a7ae56a', datetime.datetime(2023, 11, 4, 3, 20, 53), 66.05, 9.91, 75.96, 'CUST001', 'STORE005', 3, 354)
# (159, '9d4da14e-db05-4a5f-9888-3b706d009254', datetime.datetime(2023, 5, 6, 18, 52, 1), 12.25, 1.83, 14.08, 'CUST002', 'STORE003', 1, 334)
# (160, '395aca75-16c9-432e-9341-78c87464c860', datetime.datetime(2023, 4, 21, 7, 19, 1), 33.95, 4.41, 38.36, 'CUST001', 'STORE001', 1, 356)
# (161, 'e89752dd-ce37-4583-9a60-447f99d0c192', datetime.datetime(2023, 12, 25, 17, 10, 11), 22.2, 3.32, 25.52, 'CUST004', 'STORE003', 1, 305)
# (162, 'ad9c7b00-b08d-404b-8b0c-45bb37ce2031', datetime.datetime(2023, 1, 14, 2, 24, 25), 110.0, 14.3, 124.3, 'CUST002', 'STORE001', 2, 358)
# (163, '2718aafc-dbc6-4385-b0d7-8ac8d32c4537', datetime.datetime(2023, 2, 19, 11, 29, 50), 68.05, 3.4, 71.45, 'CUST008', 'STORE004', 1, 359)
# (164, '04b900d8-3887-404e-a518-ee44573c57a5', datetime.datetime(2023, 2, 20, 18, 37, 51), 118.55, 17.75, 136.3, 'CUST006', 'STORE003', 4, 360)
# (165, 'd03c4f51-f1f1-4916-a59c-bf9be0c6bfc5', datetime.datetime(2023, 11, 19, 21, 11, 37), 78.25, 9.39, 87.64, 'CUST005', 'STORE002', 5, 47)
# (166, 'ec10f4fc-6a44-4399-9e41-ca50fdd1f275', datetime.datetime(2023, 11, 15, 10, 8, 37), 118.65, 15.42, 134.07, 'CUST001', 'STORE001', 1, 51)
# (167, 'da89c6fc-e435-45c8-98fe-d0f2609a126b', datetime.datetime(2023, 8, 6, 23, 23, 39), 113.35, 16.97, 130.32, 'CUST002', 'STORE003', 5, 363)
# (168, '1f541fcf-584e-43cd-82df-ba36d735cf8e', datetime.datetime(2023, 4, 19, 17, 16, 6), 52.65, 2.63, 55.28, 'CUST006', 'STORE004', 2, 345)
# (169, '05994764-4ec1-4d0f-a840-ac92f4002252', datetime.datetime(2023, 1, 31, 11, 47, 58), 85.25, 10.23, 95.48, 'CUST002', 'STORE002', 4, 90)
# (170, '762bc9ca-c1e1-4f26-b557-0d9e43b6d3dd', datetime.datetime(2023, 11, 8, 21, 21, 40), 69.8, 9.07, 78.87, 'CUST009', 'STORE001', 1, 366)
# (171, 'bd220ce8-818e-4b83-b872-9e0bb16d0d71', datetime.datetime(2023, 8, 3, 7, 58, 6), 40.9, 4.91, 45.81, 'CUST007', 'STORE002', 2, 333)
# (2879, 'a833d104-a37f-4f4e-b09e-cb8818a3978d', datetime.datetime(2023, 9, 14, 14, 48, 23), 62.4, 9.34, 71.74, 'CUST006', 'STORE003', 3, 58)
# (172, 'd277a0dc-2147-41a9-be95-f0bf5a16acba', datetime.datetime(2023, 6, 16, 6, 26, 21), 87.5, 4.38, 91.88, 'CUST003', 'STORE004', 2, 368)
# (173, 'cba0df7e-7569-4aaf-8373-30961808d768', datetime.datetime(2023, 11, 3, 8, 41, 7), 135.2, 16.22, 151.42, 'CUST003', 'STORE002', 5, 95)
# (174, 'dc59ee1b-f094-4b3e-96dc-1f4628c19fcd', datetime.datetime(2023, 6, 30, 15, 16, 27), 27.75, 4.16, 31.91, 'CUST004', 'STORE003', 2, 370)
# (175, 'd73ce82f-1bc7-421d-a973-156ec2cbae95', datetime.datetime(2023, 2, 8, 2, 29, 52), 92.25, 11.07, 103.32, 'CUST004', 'STORE002', 3, 89)
# (176, '9927dfe5-df88-4bee-bdca-69a53d9d2142', datetime.datetime(2023, 9, 3, 6, 54, 45), 47.4, 5.69, 53.09, 'CUST001', 'STORE002', 2, 23)
# (177, '9ba545e6-9956-4558-8281-8ef947a335d9', datetime.datetime(2023, 12, 7, 1, 17, 26), 99.1, 12.88, 111.98, 'CUST005', 'STORE001', 4, 373)
# (178, '2dad6614-3171-457e-a5ac-e972f7cf4637', datetime.datetime(2023, 8, 18, 2, 16, 36), 107.45, 16.12, 123.57, 'CUST006', 'STORE005', 3, 27)
# (179, 'ef27b149-9465-48a1-b790-6c92db91f74e', datetime.datetime(2023, 7, 17, 6, 28, 27), 85.3, 11.09, 96.39, 'CUST005', 'STORE001', 4, 353)
# (180, '2dd915aa-6390-45ed-8aa3-3295de7ca06f', datetime.datetime(2023, 7, 23, 2, 16, 17), 37.3, 5.59, 42.89, 'CUST003', 'STORE005', 2, 376)
# (181, '365e5494-66e1-4a97-bac5-ebec8eb83fc6', datetime.datetime(2023, 12, 10, 22, 14, 14), 59.75, 8.96, 68.71, 'CUST002', 'STORE005', 3, 377)
# (182, 'a9c10bfb-4696-49b7-881f-8fb0ce280e7a', datetime.datetime(2023, 4, 19, 20, 50, 39), 87.05, 10.45, 97.5, 'CUST003', 'STORE002', 2, 345)
# (183, '46f83d06-ca9b-4f46-912e-25fd1acb4d63', datetime.datetime(2023, 4, 4, 15, 44, 34), 24.2, 2.9, 27.1, 'CUST009', 'STORE002', 5, 379)
# (184, '2c1c4e25-4ead-42b1-81b3-9f54f293066c', datetime.datetime(2023, 7, 28, 20, 47, 50), 96.4, 12.53, 108.93, 'CUST004', 'STORE001', 4, 311)
# (185, '1459b8ef-f2d4-4a3c-bbf3-ea05dbec1b5e', datetime.datetime(2023, 6, 29, 20, 32, 3), 96.05, 14.41, 110.46, 'CUST001', 'STORE005', 3, 50)
# (186, '2fe00676-7423-45e6-a6cb-c11ef0ea0de9', datetime.datetime(2023, 5, 22, 2, 36, 45), 78.1, 3.9, 82.0, 'CUST008', 'STORE004', 4, 382)
# (187, '9f35c188-5da9-45cc-a3ed-1d85a339b04a', datetime.datetime(2023, 11, 27, 14, 56, 20), 35.25, 4.58, 39.83, 'CUST008', 'STORE001', 4, 383)
# (188, 'f15ed41b-4af5-4e8e-92d1-9c3bd89e9172', datetime.datetime(2023, 4, 30, 21, 14, 18), 33.4, 4.34, 37.74, 'CUST008', 'STORE001', 2, 384)
# (189, '8a164a35-13e4-49bb-93b5-cb17330253fb', datetime.datetime(2023, 9, 9, 17, 15, 18), 68.55, 8.23, 76.78, 'CUST008', 'STORE002', 2, 30)
# (190, '799357df-16ab-458b-9e60-6116a489cce3', datetime.datetime(2023, 2, 13, 14, 38, 1), 71.8, 10.77, 82.57, 'CUST003', 'STORE005', 5, 386)
# (191, '06cdba0e-f39e-4f55-9daf-67691b45d5ff', datetime.datetime(2023, 4, 4, 7, 10, 14), 88.45, 13.27, 101.72, 'CUST010', 'STORE005', 3, 379)
# (192, 'dc6f0856-1d2e-498b-8b1c-19a02b2e1ba0', datetime.datetime(2023, 10, 29, 9, 2, 50), 69.1, 3.46, 72.55, 'CUST010', 'STORE004', 3, 388)
# (193, '30bf5333-67ff-4acc-ac2f-13960aaf31f4', datetime.datetime(2023, 5, 31, 19, 52, 59), 73.05, 3.65, 76.7, 'CUST004', 'STORE004', 1, 389)
# (194, '922abb0c-631c-48b2-aa1e-94981aab37df', datetime.datetime(2023, 1, 26, 5, 53, 40), 103.5, 15.5, 119.0, 'CUST009', 'STORE003', 5, 390)
# (195, '18cc8320-69b8-4339-a292-668c2f10528d', datetime.datetime(2023, 8, 17, 5, 49, 40), 40.8, 6.12, 46.92, 'CUST004', 'STORE005', 1, 326)
# (196, '6ffe8e11-2972-4659-bbdb-1a7ff122849e', datetime.datetime(2023, 2, 23, 20, 5, 57), 104.2, 13.55, 117.75, 'CUST001', 'STORE001', 1, 13)
# (197, '9337fa82-cb40-4e1f-97bc-e96a3200809b', datetime.datetime(2023, 8, 7, 9, 19, 39), 22.0, 2.64, 24.64, 'CUST008', 'STORE002', 3, 393)
# (198, '23158e97-45f5-4943-adf3-44f61796d813', datetime.datetime(2023, 5, 31, 6, 18, 51), 62.6, 7.51, 70.11, 'CUST006', 'STORE002', 1, 389)
# (199, 'c38aea8f-a9a6-447c-8518-92f834937746', datetime.datetime(2023, 3, 13, 13, 13, 29), 54.15, 8.12, 62.27, 'CUST003', 'STORE005', 5, 329)
# (200, '92f692bf-9299-416b-95a3-f8cb7a3c188f', datetime.datetime(2023, 3, 10, 5, 33, 52), 112.5, 5.62, 118.12, 'CUST008', 'STORE004', 1, 396)
# (201, '7978bfa5-36f6-467e-865d-7f5e9973b807', datetime.datetime(2023, 8, 10, 8, 41, 5), 88.95, 13.34, 102.29, 'CUST005', 'STORE005', 1, 397)
# (202, '2db9054c-e05b-4fc7-9761-cd5e4fe555a6', datetime.datetime(2023, 6, 9, 8, 25, 49), 26.25, 3.41, 29.66, 'CUST010', 'STORE001', 2, 398)
# (203, '802b1321-2b3d-411d-96ef-3c3ae7c98242', datetime.datetime(2023, 1, 26, 17, 58, 1), 75.0, 9.75, 84.75, 'CUST003', 'STORE001', 4, 390)
# (204, '7d11252c-6fb8-4b37-a599-f65b9d9c8bad', datetime.datetime(2023, 10, 2, 11, 39, 23), 63.05, 7.57, 70.62, 'CUST009', 'STORE002', 3, 400)
# (205, '9ad95536-6c2e-4749-bc1e-4b69feadd29b', datetime.datetime(2023, 10, 5, 12, 47, 43), 28.25, 3.67, 31.92, 'CUST008', 'STORE001', 4, 62)
# (206, '36d1a86b-8597-4cfb-bc7d-267b276f1b44', datetime.datetime(2023, 5, 10, 19, 20, 26), 87.8, 11.41, 99.21, 'CUST001', 'STORE001', 2, 402)
# (207, '2c57ed1b-0838-459c-92e6-817336817226', datetime.datetime(2023, 8, 5, 17, 43, 57), 36.15, 4.7, 40.85, 'CUST005', 'STORE001', 2, 14)
# (208, '76fb19dd-4785-468c-94b1-3a91fa6839d3', datetime.datetime(2023, 11, 28, 11, 1, 33), 76.15, 11.42, 87.57, 'CUST003', 'STORE005', 1, 404)
# (209, '4081cd3e-e24e-4964-9f5b-458c6e8be02e', datetime.datetime(2023, 12, 18, 13, 7, 41), 82.1, 10.67, 92.77, 'CUST008', 'STORE001', 4, 405)
# (210, '60a43e52-8a68-48ff-9ee7-30fd008209d2', datetime.datetime(2023, 9, 29, 20, 11, 7), 78.0, 10.14, 88.14, 'CUST009', 'STORE001', 4, 406)
# (211, '2c758154-b487-46e4-9823-35c50dc92f4e', datetime.datetime(2023, 1, 13, 17, 51, 32), 68.0, 8.84, 76.84, 'CUST008', 'STORE001', 2, 407)
# (212, '89997e0a-b333-4897-af0e-f871f77d7ce0', datetime.datetime(2023, 6, 10, 8, 6, 39), 24.4, 2.93, 27.33, 'CUST003', 'STORE002', 3, 313)
# (213, '61f15976-91e7-44a8-bbc8-fe0d5e7e90ff', datetime.datetime(2023, 2, 8, 10, 15, 11), 50.9, 7.62, 58.52, 'CUST004', 'STORE003', 3, 89)
# (214, '65d0861d-0502-4ca1-aaf7-d2ed23caf5e0', datetime.datetime(2023, 10, 31, 7, 47, 41), 27.25, 1.36, 28.61, 'CUST006', 'STORE004', 1, 410)
# (215, 'c1247ad0-5c33-49de-8203-3555fbda187a', datetime.datetime(2023, 10, 2, 6, 18, 11), 85.55, 12.81, 98.36, 'CUST003', 'STORE003', 1, 400)
# (216, '683ef3d8-90ba-4988-b2ed-6ee7e5e70bcb', datetime.datetime(2023, 10, 28, 4, 46, 33), 46.7, 7.0, 53.7, 'CUST004', 'STORE005', 5, 412)
# (217, '8fc9ec45-b085-4fb9-b38c-bf30d3ddae3a', datetime.datetime(2023, 3, 18, 15, 26, 31), 13.6, 1.63, 15.23, 'CUST009', 'STORE002', 5, 322)
# (218, 'a37a9351-76e9-459c-81af-d207a66a0a05', datetime.datetime(2023, 1, 5, 19, 55, 48), 76.65, 11.5, 88.15, 'CUST004', 'STORE005', 2, 81)
# (219, '7c2f6efe-d38a-43ac-9e83-649580d26ed8', datetime.datetime(2023, 6, 29, 13, 19, 42), 126.1, 16.39, 142.49, 'CUST005', 'STORE001', 1, 50)
# (220, 'c43dd9f1-1732-46a3-9c54-311c0404cbc2', datetime.datetime(2023, 7, 22, 14, 20, 17), 52.75, 7.91, 60.66, 'CUST003', 'STORE005', 1, 416)
# (221, 'a96460b3-51c5-4ad9-bb89-2464704ac8de', datetime.datetime(2023, 4, 15, 10, 38, 34), 80.1, 10.41, 90.51, 'CUST008', 'STORE001', 4, 417)
# (222, 'd79ffb87-bdf7-4ba3-9668-2c8caa4ef6f5', datetime.datetime(2023, 9, 5, 16, 0, 15), 51.0, 7.65, 58.65, 'CUST004', 'STORE005', 1, 418)
# (223, '6b428102-c24b-478a-b73f-e4b367141638', datetime.datetime(2023, 5, 25, 9, 39, 42), 54.85, 6.58, 61.43, 'CUST008', 'STORE002', 5, 419)
# (224, '5b22453a-6dfb-44da-be62-186479d0f4f6', datetime.datetime(2023, 1, 16, 11, 28, 20), 40.5, 4.86, 45.36, 'CUST007', 'STORE002', 3, 84)
# (225, '13cb090a-7003-4378-9345-d1f0740f74ed', datetime.datetime(2023, 8, 19, 13, 53, 16), 71.6, 8.59, 80.19, 'CUST010', 'STORE002', 3, 421)
# (226, 'b749b78f-b370-4dc3-ad9b-6dc6dbe3e547', datetime.datetime(2023, 9, 13, 9, 21, 55), 43.55, 5.23, 48.78, 'CUST001', 'STORE002', 4, 59)
# (1224, 'e5d50945-ccd5-4e83-aee6-5f56eeab68ba', datetime.datetime(2023, 1, 10, 5, 44, 9), 72.45, 9.42, 81.87, 'CUST005', 'STORE001', 5, 320)
# (227, '42ecfbb4-ce72-429c-9378-757e124ef2d1', datetime.datetime(2023, 8, 19, 21, 9, 49), 73.8, 3.69, 77.49, 'CUST007', 'STORE004', 4, 421)
# (228, 'b65af01b-0674-40d1-a011-b4190ac632f8', datetime.datetime(2023, 3, 8, 11, 6, 24), 103.35, 15.48, 118.83, 'CUST009', 'STORE003', 5, 424)
# (229, 'c4e63ddd-1335-483c-82b9-0bac597bf306', datetime.datetime(2023, 9, 24, 16, 18, 48), 67.15, 8.73, 75.88, 'CUST003', 'STORE001', 2, 425)
# (230, '9623c9eb-09a3-4b13-b4cf-9f6d98b1d40f', datetime.datetime(2023, 12, 15, 21, 27, 19), 43.2, 2.16, 45.36, 'CUST005', 'STORE004', 4, 426)
# (231, '6e31143b-60c4-43c2-8301-153f4cfbb255', datetime.datetime(2023, 8, 12, 22, 24, 48), 117.7, 17.66, 135.36, 'CUST008', 'STORE005', 4, 427)
# (232, 'd0bd5578-b1cd-4834-9088-828491c67700', datetime.datetime(2023, 8, 17, 0, 33, 3), 33.5, 1.68, 35.17, 'CUST009', 'STORE004', 4, 326)
# (233, '91173395-99ae-4263-a9ae-0920a2b098ba', datetime.datetime(2023, 9, 11, 18, 3, 39), 114.8, 17.19, 131.99, 'CUST004', 'STORE003', 1, 339)
# (234, '2e539055-7c50-41ac-9b0c-1b586c58be2f', datetime.datetime(2023, 8, 13, 14, 48, 15), 94.2, 14.13, 108.33, 'CUST003', 'STORE005', 2, 94)
# (235, '42a53cad-454f-4e41-b9e7-da04dfdded50', datetime.datetime(2023, 10, 29, 9, 2, 25), 68.8, 8.26, 77.06, 'CUST005', 'STORE002', 5, 388)
# (236, '93658fc2-e555-4878-889d-c0fd6049e86e', datetime.datetime(2023, 1, 15, 12, 7, 32), 77.8, 11.65, 89.45, 'CUST007', 'STORE003', 5, 432)
# (237, 'a7494712-b7ce-4648-bc87-258b8d5e9899', datetime.datetime(2023, 9, 3, 1, 18, 38), 21.35, 2.78, 24.13, 'CUST001', 'STORE001', 1, 23)
# (238, '7550391a-808a-4cbc-94e6-af9967b8d054', datetime.datetime(2023, 12, 14, 13, 17, 15), 78.1, 11.72, 89.82, 'CUST007', 'STORE005', 1, 434)
# (239, '212549f5-86f3-45c5-83d2-839d74458453', datetime.datetime(2023, 12, 27, 22, 52, 33), 29.6, 4.44, 34.04, 'CUST008', 'STORE005', 2, 435)
# (240, '6e96ab6f-6829-40e3-90aa-39fce5ae6c52', datetime.datetime(2023, 9, 7, 5, 43, 7), 79.75, 11.96, 91.71, 'CUST006', 'STORE005', 4, 436)
# (241, 'be1cf85e-5960-45d9-a0f9-7fbb5359d62a', datetime.datetime(2023, 4, 13, 20, 12, 18), 25.05, 3.75, 28.8, 'CUST001', 'STORE003', 5, 437)
# (242, 'dd0dc94b-c2ed-4627-8f30-e018be4f1ed6', datetime.datetime(2023, 3, 17, 3, 37, 56), 46.2, 6.93, 53.13, 'CUST002', 'STORE005', 3, 438)
# (243, '6a4a326e-19fd-47d6-ac43-ad417f7efb12', datetime.datetime(2023, 2, 27, 21, 50, 56), 19.5, 2.92, 22.43, 'CUST009', 'STORE005', 3, 103)
# (244, 'a5f8b4a6-cd26-42fe-968c-abfc16fea2f4', datetime.datetime(2023, 9, 2, 23, 26, 15), 34.4, 4.13, 38.53, 'CUST004', 'STORE002', 2, 440)
# (245, '9c1e681a-b299-4e69-9551-60d4026fa0e2', datetime.datetime(2023, 3, 25, 19, 34, 42), 79.25, 11.89, 91.14, 'CUST005', 'STORE005', 1, 6)
# (246, '75b70f09-5c4a-4a35-8ec7-83ed26bef2fb', datetime.datetime(2023, 7, 27, 9, 53, 16), 55.45, 8.32, 63.77, 'CUST002', 'STORE005', 5, 442)
# (247, '3c885065-c8c5-43a9-bd68-aaa0c308f804', datetime.datetime(2023, 8, 19, 15, 49, 27), 26.9, 3.5, 30.4, 'CUST003', 'STORE001', 5, 421)
# (248, '1aa16121-32dd-45d7-b4d0-86ea113a9777', datetime.datetime(2023, 2, 28, 0, 48, 51), 42.35, 2.12, 44.47, 'CUST005', 'STORE004', 3, 18)
# (249, 'aa8ed177-6217-4be4-972a-f60ac21e2881', datetime.datetime(2023, 10, 12, 16, 52, 40), 55.05, 6.61, 61.66, 'CUST003', 'STORE002', 3, 75)
# (250, '1bfb6835-9822-416f-877e-233f9d291c66', datetime.datetime(2023, 11, 1, 20, 30, 14), 62.2, 7.46, 69.66, 'CUST004', 'STORE002', 4, 446)
# (251, '3893c1b5-9fa9-48b2-86c3-16b2d8c75731', datetime.datetime(2023, 3, 21, 13, 52, 15), 76.7, 11.49, 88.19, 'CUST008', 'STORE003', 5, 5)
# (252, '4d604071-3b90-4f9e-a753-2b4fa4580369', datetime.datetime(2023, 11, 9, 20, 6, 11), 121.3, 18.2, 139.5, 'CUST007', 'STORE005', 1, 448)
# (253, 'ad34e25d-693e-4793-a4ba-dec833bf40ae', datetime.datetime(2023, 4, 22, 17, 47, 44), 45.85, 6.87, 52.72, 'CUST006', 'STORE003', 5, 48)
# (254, 'eee4bdc9-995a-4ee8-9e78-65dc8f304bb5', datetime.datetime(2023, 1, 7, 17, 49, 39), 104.75, 5.24, 109.99, 'CUST007', 'STORE004', 5, 450)
# (255, '76532b1f-8683-47b3-b5c2-d7d763b09c49', datetime.datetime(2023, 6, 21, 20, 8, 27), 25.25, 3.28, 28.53, 'CUST010', 'STORE001', 2, 24)
# (256, '8c0553c3-7480-4715-9785-e5ba4bff0d4e', datetime.datetime(2023, 1, 20, 4, 18, 35), 30.25, 3.63, 33.88, 'CUST009', 'STORE002', 4, 92)
# (257, '63eee3c9-a480-4510-aa93-3421bf91543f', datetime.datetime(2023, 8, 29, 14, 41, 11), 125.5, 18.83, 144.33, 'CUST007', 'STORE005', 2, 453)
# (258, '3f24ba65-a63e-4759-9ec5-6ad12c7f5f03', datetime.datetime(2023, 6, 24, 4, 23, 10), 122.35, 18.32, 140.67, 'CUST004', 'STORE003', 3, 454)
# (259, '6e323d6d-ec4f-4cb0-9fe1-b632534c305e', datetime.datetime(2023, 4, 30, 19, 34, 45), 20.0, 2.6, 22.6, 'CUST009', 'STORE001', 1, 384)
# (260, 'f7ddb428-b8ff-492f-a3da-9127ca8d4323', datetime.datetime(2023, 5, 7, 4, 14, 37), 36.15, 4.7, 40.85, 'CUST001', 'STORE001', 4, 456)
# (261, '77133730-c70b-48a6-8f79-157384f3530c', datetime.datetime(2023, 7, 15, 12, 0, 53), 50.55, 7.57, 58.12, 'CUST007', 'STORE003', 4, 457)
# (262, 'ffa53d5e-fa93-4607-8c27-ab89d307755a', datetime.datetime(2023, 3, 13, 8, 9, 44), 53.75, 6.99, 60.74, 'CUST007', 'STORE001', 5, 329)
# (263, '21a7a377-ad42-4e74-a67b-eeb35d0dfd0e', datetime.datetime(2023, 8, 18, 1, 25, 37), 45.15, 6.77, 51.92, 'CUST007', 'STORE005', 1, 27)
# (264, '3aab9d83-cff1-44ae-9f04-13e6ca44fd76', datetime.datetime(2023, 8, 14, 19, 18, 1), 85.1, 12.76, 97.86, 'CUST008', 'STORE005', 4, 8)
# (265, '6c15366a-a4b8-481f-914b-4eb4cf119371', datetime.datetime(2023, 6, 21, 3, 8, 6), 69.45, 10.4, 79.85, 'CUST006', 'STORE003', 4, 24)
# (266, '3b7e3d7c-7b22-4653-b1a3-a914a06458cc', datetime.datetime(2023, 7, 11, 5, 43, 40), 29.5, 4.42, 33.92, 'CUST008', 'STORE005', 2, 74)
# (267, '1872f613-bd3d-4014-868d-6b511b514cb1', datetime.datetime(2023, 5, 20, 22, 34, 30), 66.9, 3.35, 70.25, 'CUST005', 'STORE004', 2, 463)
# (268, '5f3e0ad2-4b3c-4893-a183-893fc6e86930', datetime.datetime(2023, 9, 8, 14, 13, 30), 40.6, 6.08, 46.68, 'CUST002', 'STORE003', 3, 464)
# (269, 'fe04b8bf-02d6-4f10-9cc7-1f7d2ae3a665', datetime.datetime(2023, 10, 25, 4, 23, 20), 64.65, 3.23, 67.88, 'CUST005', 'STORE004', 1, 29)
# (270, 'e0eb114e-a017-437e-bef6-b78390817b96', datetime.datetime(2023, 3, 20, 3, 15, 25), 28.5, 3.42, 31.92, 'CUST002', 'STORE002', 5, 466)
# (271, '55c6c78a-c740-491c-ad72-6210a3be73c9', datetime.datetime(2023, 12, 31, 16, 3, 10), 25.7, 1.29, 26.98, 'CUST007', 'STORE004', 1, 467)
# (272, '10300ef5-905b-4e35-92cf-3ce73e96a25f', datetime.datetime(2023, 12, 16, 1, 32, 26), 50.3, 7.53, 57.83, 'CUST002', 'STORE003', 1, 15)
# (273, '226de5e4-b765-4de8-84bf-f2f129d7483d', datetime.datetime(2023, 8, 29, 11, 24, 46), 108.8, 13.06, 121.86, 'CUST005', 'STORE002', 4, 453)
# (274, 'dcf36b73-35d8-4a72-b638-36097a0716da', datetime.datetime(2023, 10, 3, 1, 35, 23), 81.3, 10.57, 91.87, 'CUST006', 'STORE001', 1, 470)
# (275, '3ef1389b-7b63-4d6e-9511-f79fda9db330', datetime.datetime(2023, 7, 26, 14, 1, 21), 69.45, 9.03, 78.48, 'CUST001', 'STORE001', 4, 471)
# (276, '39459b44-179a-41de-b7f7-d068dcd23380', datetime.datetime(2023, 6, 4, 1, 18, 29), 62.5, 9.36, 71.86, 'CUST009', 'STORE003', 3, 472)
# (277, '6ec282f2-b858-492f-a334-4e8ebd1f85d7', datetime.datetime(2023, 3, 17, 9, 4, 36), 18.35, 2.2, 20.55, 'CUST007', 'STORE002', 5, 438)
# (278, '1cf749ef-66df-4bfd-a31f-83ab6575cad1', datetime.datetime(2023, 7, 11, 20, 10, 32), 87.3, 11.35, 98.65, 'CUST001', 'STORE001', 5, 74)
# (279, '2504e31d-4ddc-4659-b603-9f48542ec02c', datetime.datetime(2023, 11, 15, 22, 40, 2), 99.5, 12.94, 112.44, 'CUST008', 'STORE001', 4, 51)
# (280, '30666ce4-6663-4686-9e51-71edb3657fbd', datetime.datetime(2023, 12, 26, 1, 17, 21), 41.9, 6.28, 48.18, 'CUST001', 'STORE005', 1, 60)
# (281, 'af6ee9dd-e76f-439b-be5d-f41301cf621f', datetime.datetime(2023, 10, 4, 20, 52, 56), 29.5, 4.42, 33.92, 'CUST010', 'STORE005', 5, 96)
# (282, 'cbba2924-87f5-4bd9-b245-849c9694ec4a', datetime.datetime(2023, 4, 26, 7, 1, 5), 119.35, 17.9, 137.25, 'CUST006', 'STORE005', 4, 478)
# (283, '6fc93ccf-a2dc-416e-8242-229d638d2d7a', datetime.datetime(2023, 5, 29, 2, 41, 27), 15.95, 0.8, 16.75, 'CUST006', 'STORE004', 5, 479)
# (284, '84b84668-7005-4385-b3b4-2bd8dab42685', datetime.datetime(2023, 4, 18, 1, 42, 6), 38.4, 5.75, 44.15, 'CUST010', 'STORE003', 4, 480)
# (285, 'e8e27919-6b63-429d-9756-4754443a1498', datetime.datetime(2023, 3, 13, 10, 19, 53), 80.2, 4.01, 84.21, 'CUST008', 'STORE004', 1, 329)
# (286, '91e9af4b-bd5b-4717-a70d-88cb782840c4', datetime.datetime(2023, 12, 18, 9, 5, 27), 78.25, 11.72, 89.97, 'CUST006', 'STORE003', 3, 405)
# (287, 'ad6e9a79-88a6-43db-9a62-37f1a26f906d', datetime.datetime(2023, 5, 21, 20, 46, 45), 67.55, 10.12, 77.67, 'CUST002', 'STORE003', 1, 2)
# (288, '86842567-14f7-42fb-9615-1e0eb75ec8a6', datetime.datetime(2023, 11, 12, 3, 52, 45), 37.9, 5.68, 43.58, 'CUST001', 'STORE003', 1, 484)
# (289, '6dc532b3-2f13-4fbd-8d6d-0fbea6196930', datetime.datetime(2023, 10, 30, 11, 8, 29), 51.1, 6.13, 57.23, 'CUST004', 'STORE002', 4, 485)
# (290, '8047763b-d729-483a-9b5e-2a30f2a32154', datetime.datetime(2023, 2, 25, 23, 59, 32), 54.5, 8.16, 62.66, 'CUST005', 'STORE003', 3, 99)
# (291, '2d38f20a-f6d8-4cc5-9fb1-c111007bf3f2', datetime.datetime(2023, 5, 3, 20, 54, 55), 52.05, 2.6, 54.65, 'CUST006', 'STORE004', 1, 487)
# (292, '864aae42-6233-4f07-be67-342578fc5ed5', datetime.datetime(2023, 6, 29, 10, 41, 28), 98.6, 4.93, 103.53, 'CUST002', 'STORE004', 1, 50)
# (293, '200d76fe-c727-4b97-ba84-873c90935186', datetime.datetime(2023, 6, 6, 19, 44, 32), 46.35, 6.03, 52.38, 'CUST004', 'STORE001', 2, 17)
# (294, '6cb402ec-6a92-4457-b6de-d49573e5579f', datetime.datetime(2023, 5, 2, 14, 52, 28), 88.75, 11.54, 100.29, 'CUST002', 'STORE001', 2, 490)
# (295, 'dac5ed43-d615-41d4-8539-986d62268e7d', datetime.datetime(2023, 12, 26, 15, 41), 40.35, 6.04, 46.39, 'CUST007', 'STORE003', 1, 60)
# (296, '1344648c-a2b7-4d5c-a7bd-89fc0228fc8e', datetime.datetime(2023, 11, 21, 6, 22, 26), 25.9, 1.29, 27.2, 'CUST007', 'STORE004', 1, 87)
# (297, 'de4b4524-4ff7-444c-99dd-9f1fc64a1f5b', datetime.datetime(2023, 4, 17, 15, 48, 39), 15.5, 0.78, 16.27, 'CUST002', 'STORE004', 2, 54)
# (298, 'ce4bd1bc-073b-4a0f-aa3c-fbd40aecc9e3', datetime.datetime(2023, 4, 15, 3, 37, 14), 60.8, 9.12, 69.92, 'CUST003', 'STORE005', 3, 417)
# (299, '15740e1b-3bdb-4923-aa06-f2f02e980290', datetime.datetime(2023, 7, 1, 1, 52, 34), 18.75, 2.81, 21.56, 'CUST009', 'STORE003', 1, 315)
# (300, '8079012e-09cd-41c2-b23c-bb8860bd00fe', datetime.datetime(2023, 7, 4, 18, 12, 18), 114.8, 14.92, 129.72, 'CUST006', 'STORE001', 1, 496)
# (301, 'bf3b4bd0-9d6b-4d48-a793-7457bb9ac77d', datetime.datetime(2023, 1, 11, 6, 53, 51), 107.2, 12.86, 120.06, 'CUST008', 'STORE002', 2, 497)
# (302, 'f73e0a0d-9b6d-4b6b-ba43-30f24538c7e4', datetime.datetime(2023, 1, 24, 11, 31, 13), 81.5, 10.6, 92.1, 'CUST003', 'STORE001', 5, 88)
# (303, '81b21827-0731-4328-9caa-63489ec509cc', datetime.datetime(2023, 3, 16, 22, 45, 57), 12.65, 1.89, 14.54, 'CUST006', 'STORE003', 5, 499)
# (304, '5240d60c-ed4e-4457-a996-7b8e07fb12c6', datetime.datetime(2023, 3, 9, 20, 52, 58), 51.4, 6.68, 58.08, 'CUST005', 'STORE001', 2, 500)
# (305, '85cfc002-5916-49e5-a3cd-cf120e4d3581', datetime.datetime(2023, 7, 13, 6, 45, 47), 117.4, 17.58, 134.98, 'CUST006', 'STORE003', 2, 318)
# (306, 'f241e93d-acc3-45d1-b7fc-1f1a97579b96', datetime.datetime(2023, 11, 12, 13, 31, 39), 58.25, 8.74, 66.99, 'CUST005', 'STORE005', 5, 484)
# (307, 'b43b62b9-bb2d-41b7-bbb9-70022499fb27', datetime.datetime(2023, 2, 16, 20, 46, 12), 90.6, 4.53, 95.13, 'CUST003', 'STORE004', 1, 503)
# (308, 'b8e87e5a-7b6c-44c9-ad30-a9f422c23c58', datetime.datetime(2023, 3, 20, 13, 19, 13), 18.2, 2.18, 20.38, 'CUST004', 'STORE002', 3, 466)
# (309, '13e1357b-6260-4c1e-80f8-2f54e9221901', datetime.datetime(2023, 6, 9, 21, 13, 8), 76.8, 11.52, 88.32, 'CUST001', 'STORE005', 1, 398)
# (310, '31fb391c-1e25-4579-ad57-0057a9936756', datetime.datetime(2023, 8, 26, 16, 18, 34), 107.35, 13.96, 121.31, 'CUST001', 'STORE001', 3, 82)
# (311, '0ae13c7a-ba23-45ad-8a3c-058fb6c3e5b5', datetime.datetime(2023, 2, 1, 18, 16, 2), 69.15, 3.46, 72.61, 'CUST002', 'STORE004', 1, 507)
# (312, '1fcd2626-8c1e-4775-b859-a3aa92eb2b62', datetime.datetime(2023, 8, 20, 5, 55, 33), 89.5, 4.48, 93.97, 'CUST003', 'STORE004', 5, 508)
# (313, 'c9a117e2-d450-4f81-9338-7c4d7f1259f9', datetime.datetime(2023, 2, 18, 9, 39, 44), 16.7, 2.5, 19.2, 'CUST010', 'STORE003', 1, 509)
# (314, 'c884e8f6-a2d7-4188-a2c5-40c886bf8858', datetime.datetime(2023, 8, 2, 23, 59, 54), 111.55, 5.58, 117.13, 'CUST004', 'STORE004', 3, 510)
# (315, 'f080a9ba-8df1-40f5-8475-6f4932a2e9f3', datetime.datetime(2023, 11, 18, 20, 11, 52), 45.25, 6.78, 52.03, 'CUST005', 'STORE003', 2, 511)
# (316, '882622fd-6751-42f4-bd1c-1e2775b4dad0', datetime.datetime(2023, 9, 11, 23, 11, 9), 78.4, 10.19, 88.59, 'CUST001', 'STORE001', 4, 339)
# (317, '225b97de-ec9f-4ecf-b885-b4cd9e78d410', datetime.datetime(2023, 10, 9, 6, 5, 26), 62.8, 3.14, 65.94, 'CUST009', 'STORE004', 4, 31)
# (318, 'eb4f6591-716c-471d-b967-4d8e3c256dd8', datetime.datetime(2023, 10, 11, 20, 47, 19), 101.75, 12.21, 113.96, 'CUST006', 'STORE002', 1, 514)
# (319, '95e76dbe-498d-4fc4-aee2-ca2dae7e56b8', datetime.datetime(2023, 1, 25, 12, 47, 9), 82.05, 12.31, 94.36, 'CUST002', 'STORE005', 5, 515)
# (320, 'cf5604b8-b5b1-4edb-a956-897acf5a541c', datetime.datetime(2023, 10, 18, 2, 20, 50), 38.1, 5.71, 43.81, 'CUST002', 'STORE005', 2, 516)
# (321, 'ca1432e5-65ed-430e-b96e-0f2bba992c62', datetime.datetime(2023, 5, 1, 12, 47, 19), 55.15, 2.76, 57.91, 'CUST008', 'STORE004', 5, 330)
# (322, '332eb6a1-a33c-446e-935b-804ab6cff6ad', datetime.datetime(2023, 7, 15, 8, 32, 5), 86.65, 12.98, 99.63, 'CUST001', 'STORE003', 3, 457)
# (323, 'ff973312-94b0-4912-a328-280a26a61cf5', datetime.datetime(2023, 2, 27, 23, 9, 36), 96.9, 4.84, 101.74, 'CUST002', 'STORE004', 2, 103)
# (324, '5c85bec7-d499-46a1-b144-2d458d160f01', datetime.datetime(2023, 3, 24, 14, 15, 28), 38.25, 4.59, 42.84, 'CUST010', 'STORE002', 2, 520)
# (325, '25a73af1-a31f-48fe-ba84-7d9a14bbdd59', datetime.datetime(2023, 1, 10, 15, 26, 24), 27.2, 4.07, 31.27, 'CUST002', 'STORE003', 4, 320)
# (326, '05dfde8d-8f91-47ea-ac12-57d65f14057f', datetime.datetime(2023, 12, 10, 9, 26, 42), 61.75, 9.26, 71.01, 'CUST008', 'STORE005', 1, 377)
# (327, '4876923d-f2bf-4ddc-aee6-c858560b9327', datetime.datetime(2023, 7, 9, 21, 51, 9), 74.15, 3.71, 77.86, 'CUST010', 'STORE004', 3, 523)
# (328, '49bfdc00-9460-44ba-afa5-04577c2adcaf', datetime.datetime(2023, 7, 25, 14, 16, 27), 29.0, 4.35, 33.35, 'CUST002', 'STORE005', 4, 524)
# (329, '73a4d9f1-3708-4c42-b5d7-e056c5a29c74', datetime.datetime(2023, 6, 2, 7, 10, 2), 32.45, 3.89, 36.34, 'CUST004', 'STORE002', 5, 525)
# (330, 'ec4507a5-69a9-4edf-ad68-391523b6e945', datetime.datetime(2023, 3, 9, 8, 21, 43), 27.5, 4.12, 31.62, 'CUST002', 'STORE005', 4, 500)
# (331, 'a1686f32-19ce-4323-b797-44e15183efd1', datetime.datetime(2023, 3, 20, 12, 21, 47), 53.75, 2.69, 56.44, 'CUST008', 'STORE004', 2, 466)
# (332, 'c351ec8d-06fb-43b6-adc1-9cb027cdb72b', datetime.datetime(2023, 5, 5, 6, 33, 31), 57.85, 8.66, 66.51, 'CUST007', 'STORE003', 5, 528)
# (333, 'c6ce2118-dd43-4d95-ab39-fe3d1a7cc39a', datetime.datetime(2023, 7, 30, 14, 54, 43), 50.1, 6.01, 56.11, 'CUST010', 'STORE002', 5, 529)
# (334, 'afa4f5b1-141e-4467-93e7-888e86d870b7', datetime.datetime(2023, 10, 2, 13, 57), 87.85, 13.16, 101.01, 'CUST001', 'STORE003', 2, 400)
# (335, 'c668595e-38b2-45f3-abc4-6145431b4896', datetime.datetime(2023, 11, 10, 21, 33, 42), 43.0, 6.45, 49.45, 'CUST007', 'STORE005', 3, 531)
# (336, '9f195dfe-2630-4663-ab30-6dc9b7479d23', datetime.datetime(2023, 9, 17, 3, 2, 10), 22.0, 3.29, 25.29, 'CUST006', 'STORE003', 4, 532)
# (1225, 'ccd7ac50-3637-4f40-98fe-8ec92737cbb7', datetime.datetime(2023, 8, 14, 21, 41, 56), 34.2, 5.12, 39.32, 'CUST008', 'STORE003', 3, 8)
# (337, 'e4f1458b-78cd-4e1f-b85a-5c62b46222e4', datetime.datetime(2023, 11, 16, 23, 36, 58), 103.65, 15.55, 119.2, 'CUST009', 'STORE005', 4, 533)
# (338, '9f596221-eea2-4c1f-ace6-95e7de04cd74', datetime.datetime(2023, 7, 7, 9, 58, 38), 94.8, 4.74, 99.54, 'CUST003', 'STORE004', 1, 534)
# (339, 'f3dde2eb-6824-45ba-a1de-b9d8bc0145fd', datetime.datetime(2023, 5, 9, 20, 12, 7), 32.1, 4.17, 36.27, 'CUST008', 'STORE001', 2, 535)
# (340, '25bdaa6f-b928-4201-adbb-9d0f17d37094', datetime.datetime(2023, 9, 1, 8, 57, 6), 52.7, 6.85, 59.55, 'CUST009', 'STORE001', 1, 536)
# (341, 'ef6884ca-d176-4e84-a960-bb6e6067170c', datetime.datetime(2023, 6, 20, 23, 55, 48), 84.8, 12.72, 97.52, 'CUST001', 'STORE005', 5, 537)
# (342, '5826cc8c-9132-4b1f-8cf4-ad5696be191a', datetime.datetime(2023, 9, 16, 1, 45, 2), 116.75, 14.01, 130.76, 'CUST005', 'STORE002', 1, 538)
# (343, 'f34a8a3a-bc6c-4f3b-93d2-0f6b8f0d4ed4', datetime.datetime(2023, 6, 7, 19, 13, 9), 104.2, 5.21, 109.41, 'CUST010', 'STORE004', 3, 539)
# (344, '97c710d8-b059-4195-95aa-9c3bbe38d004', datetime.datetime(2023, 8, 19, 18, 32, 24), 99.85, 14.95, 114.8, 'CUST010', 'STORE003', 5, 421)
# (345, 'e3104367-4a71-4cea-8096-4d0d54efd809', datetime.datetime(2023, 8, 24, 20, 9, 33), 83.45, 10.01, 93.46, 'CUST004', 'STORE002', 5, 541)
# (346, 'a50fb677-09a7-4857-b8c4-aede516ecc25', datetime.datetime(2023, 10, 21, 20, 57, 45), 114.05, 14.83, 128.88, 'CUST006', 'STORE001', 3, 542)
# ...
# (3995, '7b544d45-7be1-4e18-b68e-ca49ed548fc7', datetime.datetime(2023, 3, 23, 2, 15, 40), 113.65, 5.68, 119.33, 'CUST001', 'STORE004', 1, 1260)
# (3996, '1e33233a-b6fb-4f57-bd6a-5f69985d6395', datetime.datetime(2023, 12, 18, 0, 37, 46), 89.2, 13.36, 102.56, 'CUST003', 'STORE003', 5, 405)
# (3997, '031124ca-1616-4f8e-9957-defc24b90f6b', datetime.datetime(2023, 7, 20, 11, 1, 2), 106.05, 15.88, 121.93, 'CUST003', 'STORE003', 4, 623)
# (3998, '7453ec8f-95de-4804-a84d-68ae193eb343', datetime.datetime(2023, 6, 27, 22, 49, 58), 18.0, 2.34, 20.34, 'CUST010', 'STORE001', 4, 93)
# (3999, 'f784316b-e9d7-4c6c-95c4-48278e54067a', datetime.datetime(2023, 5, 7, 20, 1, 37), 50.85, 6.1, 56.95, 'CUST005', 'STORE002', 5, 456)
# (4000, '29ef2bd2-03d6-46cc-8439-77b35497224e', datetime.datetime(2023, 12, 24, 19, 40, 52), 56.8, 8.51, 65.31, 'CUST008', 'STORE003', 4, 568)
# (4001, '8e2ae7a2-f0a5-4892-9c85-34906fc80921', datetime.datetime(2023, 9, 24, 7, 31, 40), 20.0, 2.4, 22.4, 'CUST010', 'STORE002', 2, 425)
# (4002, 'ba772350-d9fb-4abf-9442-3bbf05fdf03d', datetime.datetime(2023, 11, 29, 4, 31, 5), 33.45, 4.35, 37.8, 'CUST009', 'STORE001', 3, 26)
# (4003, '090c39b5-11be-4c73-9b5c-b87daaaa3fd3', datetime.datetime(2023, 7, 30, 11, 8, 26), 88.95, 4.45, 93.4, 'CUST002', 'STORE004', 2, 529)
# (4004, '6d87755d-52c8-4ee4-9bad-cf12dfdd9857', datetime.datetime(2023, 10, 26, 13, 56, 22), 135.1, 20.26, 155.36, 'CUST006', 'STORE005', 2, 40)
# (4005, 'e2c89e1c-9fe7-4947-ba56-f29544da579c', datetime.datetime(2023, 9, 25, 12, 49, 33), 23.6, 3.53, 27.13, 'CUST008', 'STORE003', 2, 1332)
# (4006, 'abfcc979-43e6-4f2c-8063-a64061cc588b', datetime.datetime(2023, 7, 13, 18, 29, 49), 72.95, 10.94, 83.89, 'CUST004', 'STORE005', 3, 318)
# (4007, '88f088d8-9303-4ae7-b8d6-4268df982ebe', datetime.datetime(2023, 10, 11, 17, 38, 25), 35.3, 1.76, 37.06, 'CUST006', 'STORE004', 1, 514)
# (4008, '0b34d5b4-61f1-4774-99a0-4b7716fd8a9e', datetime.datetime(2023, 9, 8, 3, 46, 43), 46.7, 6.07, 52.77, 'CUST001', 'STORE001', 1, 464)
# (4009, '8939710a-ee94-4f5c-bb3d-720d0049b10d', datetime.datetime(2023, 2, 26, 22, 46, 22), 54.5, 8.16, 62.66, 'CUST005', 'STORE003', 1, 57)
# (4010, 'e3469b34-5203-4b1c-afc3-a8243a33ee05', datetime.datetime(2023, 8, 22, 23, 52, 25), 134.9, 20.2, 155.1, 'CUST001', 'STORE003', 4, 556)
# (4011, '62ba657e-6a8b-4c2d-a452-c01912f569d3', datetime.datetime(2023, 1, 8, 14, 8, 43), 77.3, 10.05, 87.35, 'CUST006', 'STORE001', 2, 33)
# (4012, '3c5d8e22-a5d5-4b02-8b3f-1bf124ced623', datetime.datetime(2023, 10, 18, 19, 8, 15), 41.6, 6.23, 47.83, 'CUST005', 'STORE003', 2, 516)
# (4013, 'b237c546-6cf7-4228-939d-5aaf1bf847d8', datetime.datetime(2023, 11, 20, 17, 11, 44), 68.15, 8.86, 77.01, 'CUST007', 'STORE001', 1, 626)
# (4014, 'c7aa6fb6-c9e9-4814-a3e3-ef8c7da20fde', datetime.datetime(2023, 8, 20, 12, 41, 56), 93.8, 11.26, 105.06, 'CUST010', 'STORE002', 5, 508)
# (4015, '81c03412-9601-4321-8fbd-88d9b0da166b', datetime.datetime(2023, 4, 11, 14, 50, 9), 52.95, 7.94, 60.89, 'CUST008', 'STORE005', 4, 856)
# (4016, 'aa1fb7bd-0bb2-4e3b-8f43-be1f724033da', datetime.datetime(2023, 12, 14, 2, 25, 29), 59.3, 2.96, 62.27, 'CUST005', 'STORE004', 4, 434)
# (4017, '67d31543-6e51-489c-9263-3f32f22d8a62', datetime.datetime(2023, 10, 27, 19, 33, 44), 32.15, 4.18, 36.33, 'CUST005', 'STORE001', 5, 878)
# (4018, '7af09a91-29e8-4f8a-987d-54357df925d5', datetime.datetime(2023, 12, 11, 20, 15, 1), 87.15, 10.46, 97.61, 'CUST010', 'STORE002', 3, 335)
# (4019, 'e22346de-f066-4d6b-9068-231c9e875d10', datetime.datetime(2023, 7, 28, 7, 54, 35), 69.0, 10.33, 79.33, 'CUST005', 'STORE003', 1, 311)
# (4020, '240e1cd3-fe67-4283-8b84-1df0621c5d7c', datetime.datetime(2023, 12, 23, 8, 40, 10), 51.2, 7.68, 58.88, 'CUST009', 'STORE005', 2, 685)
# (4021, '12de22a9-2f19-4faf-8e64-2bc1d0244223', datetime.datetime(2023, 9, 22, 17, 50, 34), 74.9, 9.74, 84.64, 'CUST001', 'STORE001', 2, 1269)
# (4022, '3ed9022c-5b25-4b5c-8f53-98da1ebc00b2', datetime.datetime(2023, 9, 5, 16, 55, 33), 23.5, 3.52, 27.02, 'CUST007', 'STORE005', 4, 418)
# (4023, '91d6da8b-df72-463e-937a-a7fd3c1f4204', datetime.datetime(2023, 6, 3, 22, 29, 53), 97.95, 4.9, 102.85, 'CUST003', 'STORE004', 5, 346)
# (4024, '4340b15c-b094-4dc1-856c-52e90292b551', datetime.datetime(2023, 10, 30, 18, 25, 19), 18.8, 2.82, 21.62, 'CUST004', 'STORE003', 2, 485)
# (4025, 'f8a070bd-258c-46f0-8206-75c36ee88b11', datetime.datetime(2023, 6, 22, 1, 41, 52), 36.0, 5.4, 41.4, 'CUST007', 'STORE005', 1, 884)
# (4026, 'd71eba70-86e8-42f1-8b05-574611c8bb6a', datetime.datetime(2023, 11, 23, 22, 30, 26), 31.05, 4.04, 35.09, 'CUST009', 'STORE001', 3, 343)
# (4027, 'cbadd5d1-1352-4a6b-a90b-9a3fec0d4ed8', datetime.datetime(2023, 3, 1, 5, 30, 8), 27.5, 4.12, 31.62, 'CUST006', 'STORE003', 5, 100)
# (4028, '4854f2db-83e0-4b49-bd30-45edb9bfbef2', datetime.datetime(2023, 10, 26, 16, 38, 38), 118.95, 5.95, 124.9, 'CUST008', 'STORE004', 1, 40)
# (4029, 'b41f0502-6bd2-43f0-b8fd-ab63b6a2e798', datetime.datetime(2023, 10, 26, 3, 15, 14), 102.0, 12.24, 114.24, 'CUST002', 'STORE002', 1, 40)
# (4030, '6f651dab-3fc0-4429-95ab-1b683a2cabe5', datetime.datetime(2023, 9, 18, 19, 7, 59), 92.35, 12.01, 104.36, 'CUST002', 'STORE001', 1, 1018)
# (4031, 'c2403070-a9e8-442c-9789-805b6e03efd2', datetime.datetime(2023, 1, 19, 14, 22, 34), 67.75, 8.13, 75.88, 'CUST001', 'STORE002', 2, 1019)
# (4032, '884bed59-ec62-4dd1-abda-955aadc0a919', datetime.datetime(2023, 12, 5, 0, 8, 25), 89.35, 4.47, 93.82, 'CUST006', 'STORE004', 5, 85)
# (4033, 'ce5c5f24-f7b9-4afb-9536-aebe65d437ca', datetime.datetime(2023, 10, 3, 21, 18, 52), 41.75, 6.26, 48.01, 'CUST009', 'STORE005', 4, 470)
# (4034, 'b300b28a-b1c6-41bf-8d7b-a4e5ba61632a', datetime.datetime(2023, 8, 24, 18, 14, 44), 38.65, 1.93, 40.58, 'CUST008', 'STORE004', 3, 541)
# (4035, '71395f63-df95-49e6-bd64-b1103b685113', datetime.datetime(2023, 10, 16, 16, 37, 31), 86.8, 10.42, 97.22, 'CUST008', 'STORE002', 3, 34)
# (4036, '5d25e015-79f7-4161-826b-e01c4b488fa4', datetime.datetime(2023, 9, 19, 17, 10, 7), 80.4, 12.04, 92.44, 'CUST008', 'STORE003', 1, 792)
# (4037, '41eae335-e20a-4927-b604-7f248bd04cb6', datetime.datetime(2023, 12, 4, 0, 37, 15), 70.0, 3.5, 73.5, 'CUST008', 'STORE004', 2, 337)
# (4038, '0673441a-d061-4937-ab65-e6853246d5f5', datetime.datetime(2023, 2, 28, 1, 18, 40), 36.5, 4.38, 40.88, 'CUST006', 'STORE002', 3, 18)
# (4039, 'bd6f48b8-b58c-4c32-80fb-ad650d9eb3df', datetime.datetime(2023, 2, 26, 12, 59, 51), 50.4, 6.55, 56.95, 'CUST005', 'STORE001', 2, 57)
# (4040, 'da90c461-dad3-4ff7-a10a-3f4cf74e05e9', datetime.datetime(2023, 1, 16, 12, 15, 51), 55.75, 8.35, 64.1, 'CUST009', 'STORE003', 5, 84)
# (4041, 'f316209c-550e-42ba-9f30-8268aa41a042', datetime.datetime(2023, 4, 22, 11, 17, 44), 24.6, 3.68, 28.28, 'CUST010', 'STORE003', 1, 48)
# (4042, '5d2fbe69-7eb1-48ef-8f75-fedc5e718da9', datetime.datetime(2023, 4, 11, 7, 53, 29), 72.55, 9.43, 81.98, 'CUST009', 'STORE001', 5, 856)
# (4043, '524ab1da-153b-43fd-8b6e-8c35e264386a', datetime.datetime(2023, 10, 20, 1, 54, 52), 37.9, 1.9, 39.8, 'CUST001', 'STORE004', 5, 28)
# (4044, '2331c6d4-0f92-42e2-8e78-4248421ff8ea', datetime.datetime(2023, 1, 16, 10, 49, 16), 95.8, 4.79, 100.59, 'CUST010', 'STORE004', 1, 84)
# (4045, 'd2f5a66f-efa4-44b8-9f56-cd0fba00b11e', datetime.datetime(2023, 12, 5, 13, 18, 34), 47.1, 5.65, 52.75, 'CUST006', 'STORE002', 2, 85)
# (4046, '10414d92-8527-43f4-9b6a-86b226da8d58', datetime.datetime(2023, 8, 25, 8, 4, 32), 97.95, 14.69, 112.64, 'CUST002', 'STORE005', 1, 306)
# (4047, '5e94725a-fc3a-4745-abdc-fb1051a7f19d', datetime.datetime(2023, 5, 8, 16, 21, 59), 29.8, 3.58, 33.38, 'CUST008', 'STORE002', 3, 632)
# (4048, '2c59905a-7746-47c6-847b-047de128dad3', datetime.datetime(2023, 4, 8, 14, 44, 58), 82.05, 12.29, 94.34, 'CUST003', 'STORE003', 2, 965)
# (4049, '80b9f466-7a56-47d6-9186-54f83dfa179d', datetime.datetime(2023, 1, 10, 5, 12, 31), 58.0, 8.7, 66.7, 'CUST002', 'STORE005', 1, 320)
# (4050, 'ea30e8df-309e-4c8f-a5d0-aeecc8159bd8', datetime.datetime(2023, 3, 5, 7, 54, 26), 58.4, 8.75, 67.15, 'CUST010', 'STORE003', 2, 312)
# (4051, 'a5762398-5a5e-4399-828b-1b6362eb13bc', datetime.datetime(2023, 5, 5, 20, 23, 20), 26.6, 3.19, 29.79, 'CUST005', 'STORE002', 4, 528)
# (4052, 'cbe93505-4785-4799-bae0-def9ff71238a', datetime.datetime(2023, 1, 14, 8, 30, 28), 105.75, 15.86, 121.61, 'CUST010', 'STORE005', 2, 358)
# (4053, 'b08f5031-dddc-4be8-8f6e-5cde81f5657b', datetime.datetime(2023, 11, 25, 2, 24, 53), 102.25, 13.29, 115.54, 'CUST006', 'STORE001', 4, 69)
# (4054, '53f2a01f-9e16-4cc1-a28a-68e7c0f9fa9d', datetime.datetime(2023, 8, 14, 7, 32, 48), 60.4, 9.04, 69.44, 'CUST002', 'STORE003', 2, 8)
# (4055, 'dbae12b8-25f4-46d9-84ca-c53a3d60c38d', datetime.datetime(2023, 8, 18, 6, 50, 37), 104.6, 13.6, 118.2, 'CUST002', 'STORE001', 5, 27)
# (4056, '8b09dc5d-405f-4476-a456-62fd5cc4f398', datetime.datetime(2023, 4, 5, 12, 59, 5), 53.7, 2.69, 56.39, 'CUST006', 'STORE004', 3, 938)
# (4057, 'a5be79c1-2760-4fea-8b1d-b61b96b1450e', datetime.datetime(2023, 7, 26, 8, 4, 10), 24.1, 2.89, 26.99, 'CUST007', 'STORE002', 1, 471)
# (4058, '002556b9-ca63-402a-acfd-eb12952da0d7', datetime.datetime(2023, 4, 14, 16, 48, 48), 85.35, 12.78, 98.13, 'CUST009', 'STORE003', 4, 352)
# (4059, '22e33ac0-ebaf-4a63-a644-4be8cae2ed80', datetime.datetime(2023, 7, 24, 23, 46, 36), 56.9, 8.52, 65.42, 'CUST005', 'STORE003', 4, 16)
# (4060, '9cdcee9e-3a35-427d-86fc-cd047502dfdc', datetime.datetime(2023, 9, 14, 6, 23, 33), 67.75, 10.16, 77.91, 'CUST005', 'STORE005', 5, 58)
# (4061, 'ad05c135-c351-4dfe-9a7a-a7800c36bd31', datetime.datetime(2023, 1, 7, 13, 49, 24), 36.25, 5.44, 41.69, 'CUST006', 'STORE005', 4, 450)
# (4062, '6a133b9f-c6c1-4d6f-8e9c-75922556897c', datetime.datetime(2023, 9, 29, 23, 33, 2), 61.1, 7.33, 68.43, 'CUST008', 'STORE002', 3, 406)
# (4063, '62ce9b23-30cb-4253-95cc-95595807f6bf', datetime.datetime(2023, 3, 8, 18, 13, 41), 34.35, 4.47, 38.82, 'CUST001', 'STORE001', 1, 424)
# (4064, '7770a8a9-feab-4119-980d-e5f8b5d7e72b', datetime.datetime(2023, 2, 6, 15, 39, 14), 124.9, 14.99, 139.89, 'CUST002', 'STORE002', 1, 309)
# (4065, 'dcc0ef79-0447-48e0-82cc-b36b1c0edb70', datetime.datetime(2023, 11, 3, 14, 30, 2), 116.75, 5.84, 122.59, 'CUST005', 'STORE004', 2, 95)
# (4066, 'ed260585-b9f8-4e16-93ae-57504c51e3bf', datetime.datetime(2023, 5, 22, 20, 15, 32), 38.7, 5.81, 44.51, 'CUST001', 'STORE005', 5, 382)
# (4067, 'bbdce3fe-a5e0-451f-b5dd-8d907f059f9e', datetime.datetime(2023, 3, 12, 4, 6, 47), 20.0, 2.6, 22.6, 'CUST006', 'STORE001', 2, 1504)
# (4068, 'b7610f3a-0c53-41bc-bccd-de8cb5e04499', datetime.datetime(2023, 12, 30, 9, 13, 46), 23.0, 1.15, 24.15, 'CUST004', 'STORE004', 5, 952)
# (4069, '21576fab-062f-4e1e-a6ba-e99e4c93c640', datetime.datetime(2023, 9, 19, 4, 21, 51), 115.4, 13.85, 129.25, 'CUST005', 'STORE002', 5, 792)
# (4070, '21816e9c-2908-456c-acee-c1afa4908635', datetime.datetime(2023, 10, 15, 19, 59, 58), 52.3, 6.28, 58.58, 'CUST009', 'STORE002', 1, 349)
# (4071, '6cf77d6d-d65f-46f1-8cba-bd245d25d5dc', datetime.datetime(2023, 11, 30, 12, 26, 5), 57.5, 2.88, 60.38, 'CUST006', 'STORE004', 1, 49)
# (4072, '6ccfb0ff-41db-49aa-993d-81b6f72a20c3', datetime.datetime(2023, 7, 9, 9, 49, 29), 58.4, 7.01, 65.41, 'CUST005', 'STORE002', 5, 523)
# (4073, '88775e0d-10ff-46ea-8988-a8a0ccae5abf', datetime.datetime(2023, 5, 2, 10, 57, 29), 55.15, 2.76, 57.91, 'CUST007', 'STORE004', 1, 490)
# (4074, 'c0b9a9b8-d3bb-4d3f-b12b-b71dfef21718', datetime.datetime(2023, 8, 3, 17, 29, 23), 52.65, 7.9, 60.55, 'CUST007', 'STORE005', 5, 333)
# (4075, '6556c840-69ec-43eb-b9ec-3df74d827b28', datetime.datetime(2023, 1, 10, 5, 9, 20), 102.35, 15.33, 117.68, 'CUST002', 'STORE003', 3, 320)
# (4076, '6f732f80-bc9e-44ae-bf41-25dd27c89921', datetime.datetime(2023, 9, 25, 22, 25, 2), 134.8, 16.18, 150.98, 'CUST003', 'STORE002', 4, 1332)
# (4077, 'ae96a3a6-d8c2-4a75-96f2-6cdc0002fb7f', datetime.datetime(2023, 6, 1, 10, 37, 50), 49.45, 7.42, 56.87, 'CUST007', 'STORE005', 2, 1093)
# (4078, '43ab7b1d-fa04-4dae-afcc-122a6b5f4c10', datetime.datetime(2023, 6, 23, 18, 9, 48), 19.25, 2.88, 22.13, 'CUST008', 'STORE003', 2, 44)
# (4079, '19c2542e-01cb-46a1-a228-0caa05ffad81', datetime.datetime(2023, 2, 1, 13, 44, 44), 104.9, 5.25, 110.15, 'CUST009', 'STORE004', 3, 507)
# (4080, '64bf5db9-c493-4b0b-938d-f8252111fe34', datetime.datetime(2023, 8, 12, 12, 59, 16), 14.8, 2.22, 17.02, 'CUST005', 'STORE003', 2, 427)
# (4081, '986d5367-3ea7-4a00-ba62-11deb7a196f4', datetime.datetime(2023, 12, 2, 4, 17, 7), 75.6, 3.78, 79.38, 'CUST006', 'STORE004', 2, 344)
# (4082, '87a9ae7d-b0be-446e-a52c-ee03c9e74e78', datetime.datetime(2023, 12, 15, 20, 48, 43), 86.6, 4.33, 90.93, 'CUST007', 'STORE004', 5, 426)
# (4083, 'edf107c7-bfd6-49da-88a2-221c2895e814', datetime.datetime(2023, 8, 6, 15, 12, 25), 31.2, 4.06, 35.26, 'CUST006', 'STORE001', 4, 363)
# (4084, '937c0ad5-14c7-42fc-90c1-4cfbd2ac19e8', datetime.datetime(2023, 1, 18, 19, 59, 45), 13.7, 2.06, 15.76, 'CUST007', 'STORE005', 5, 565)
# (4085, '71ad7075-f39b-4916-b5aa-81ad57bd287f', datetime.datetime(2023, 1, 27, 11, 8, 51), 62.7, 9.4, 72.1, 'CUST002', 'STORE005', 2, 1634)
# (4086, 'be9017d8-a6ad-4f1f-ad47-ffe5f78bdf07', datetime.datetime(2023, 7, 2, 6, 47, 15), 29.05, 4.35, 33.4, 'CUST010', 'STORE003', 3, 722)
# (4087, '3343a655-8055-451b-a5a5-21c27ccb6a94', datetime.datetime(2023, 3, 31, 13, 3, 56), 66.75, 10.01, 76.76, 'CUST008', 'STORE005', 3, 783)
# (4088, '0b5becdc-6b08-4743-9154-64e91b4080a5', datetime.datetime(2023, 1, 6, 2, 30, 52), 22.35, 3.35, 25.7, 'CUST009', 'STORE003', 1, 795)
# (4089, 'd68a223b-f4ec-460b-83a3-7b74f0e4294a', datetime.datetime(2023, 9, 12, 1, 51, 26), 64.95, 9.73, 74.68, 'CUST002', 'STORE003', 2, 22)
# (4090, '61774def-d85a-4243-a3f0-e078dd2bf8f5', datetime.datetime(2023, 10, 27, 19, 34, 38), 89.6, 13.44, 103.04, 'CUST001', 'STORE005', 4, 878)
# (4091, 'd628441e-a65d-490b-9890-e3e42865033b', datetime.datetime(2023, 6, 3, 18, 37, 16), 33.15, 4.97, 38.12, 'CUST010', 'STORE005', 5, 346)
# (4092, '5fa4f59a-abb1-4c29-904f-c758bae43c91', datetime.datetime(2023, 11, 3, 7, 5, 50), 16.9, 2.53, 19.43, 'CUST008', 'STORE005', 5, 95)
# (4093, 'fe92bbca-70b2-4887-a03b-976ff52565ca', datetime.datetime(2023, 10, 20, 5, 9, 56), 82.6, 10.74, 93.34, 'CUST009', 'STORE001', 2, 28)
# (4094, 'c2adb645-8e57-474f-bc47-874d6462d2dd', datetime.datetime(2023, 2, 2, 2, 15, 1), 55.3, 8.28, 63.58, 'CUST001', 'STORE003', 5, 654)
# (4095, '78fa141d-d9e9-4876-a70c-8386ccbdb6b0', datetime.datetime(2023, 8, 30, 23, 28, 45), 52.85, 2.64, 55.49, 'CUST008', 'STORE004', 5, 1561)
# (4096, 'eb898329-121b-4e5e-bd82-9eba55070af6', datetime.datetime(2023, 8, 13, 16, 17, 8), 39.7, 5.95, 45.65, 'CUST001', 'STORE003', 2, 94)
# (4097, '1afccb2c-6e6c-4c67-8434-5bba9b703272', datetime.datetime(2023, 1, 31, 22, 40, 46), 81.4, 10.58, 91.98, 'CUST002', 'STORE001', 3, 90)
# (4098, 'ab7f8cfa-addd-460f-a0ec-23a55acd9e67', datetime.datetime(2023, 12, 1, 23, 54, 8), 25.65, 3.84, 29.49, 'CUST008', 'STORE003', 2, 681)
# (4099, 'a333b7e2-7fb5-452c-81a5-627222976503', datetime.datetime(2023, 12, 26, 1, 16, 46), 92.7, 4.64, 97.34, 'CUST010', 'STORE004', 3, 60)
# (4100, 'af479bb8-d020-4881-a1b8-12df096ce78f', datetime.datetime(2023, 8, 19, 10, 29, 2), 58.1, 8.71, 66.81, 'CUST003', 'STORE005', 4, 421)
# (4101, 'ed5126f3-4731-44b6-baf1-289e6f348c49', datetime.datetime(2023, 12, 3, 6, 56, 27), 96.1, 14.41, 110.51, 'CUST006', 'STORE005', 5, 1009)
# (4102, '5dd879f8-9f8a-49ce-8e95-e0bf136e0be2', datetime.datetime(2023, 5, 4, 10, 59, 22), 26.4, 3.17, 29.57, 'CUST001', 'STORE002', 4, 911)
# (4103, 'b5f7b5db-77a3-41d0-b3f0-e58e462c104e', datetime.datetime(2023, 9, 18, 0, 42, 16), 56.7, 6.8, 63.5, 'CUST008', 'STORE002', 5, 1018)
# (4104, 'ca8519f4-8565-4dc0-b9c4-af847e67f4b3', datetime.datetime(2023, 6, 20, 21, 19, 37), 46.5, 2.33, 48.83, 'CUST004', 'STORE004', 1, 537)
# (4105, '62732617-6afa-45c7-b02a-48c293f18d8c', datetime.datetime(2023, 2, 2, 19, 15, 13), 124.45, 18.67, 143.12, 'CUST009', 'STORE005', 4, 654)
# (4106, '10bdb339-8191-4a25-9598-968ba12c1910', datetime.datetime(2023, 9, 24, 6, 5, 40), 27.2, 4.07, 31.27, 'CUST010', 'STORE003', 1, 425)
# (4107, '5457fc0c-18ed-476b-961b-24632a96bcc5', datetime.datetime(2023, 4, 28, 3, 10, 22), 26.65, 1.33, 27.98, 'CUST010', 'STORE004', 3, 846)

# %%
cursor.close()
# Close the connection
connection.close()
